# %% [markdown]
# # Graph metrics with R

# %%
install.packages("igraph")
# Out:
# Installing package into ‘/home/antoine/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("igraph"):
# “installation of package ‘igraph’ had non-zero exit status”

# %%
library(igraph)
# Out:
# Error in library(igraph): there is no package called ‘igraph’
# Traceback:
#
# 1. library(igraph)

# %%
g <- read.graph("../data/processed/g.graphml", format = "graphml")
# Out:
# Error in read.graph("../data/processed/g.graphml", format = "graphml"): could not find function "read.graph"
# Traceback:

# %%
!
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:7: unexpected symbol
# 1: !sudo apt
#           ^
# Traceback:
