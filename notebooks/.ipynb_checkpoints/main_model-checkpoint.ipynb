# %% [markdown]
# # Main model

# %%
# !pip3.6 install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in /home/antoine/.local/lib/python3.6/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/antoine/.local/lib/python3.6/site-packages (from sklearn) (0.23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/antoine/.local/lib/python3.6/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.1)
# Requirement already satisfied: scipy>=0.19.1 in /home/antoine/.local/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /home/antoine/.local/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.16.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# data
import pandas as pd
import math
import numpy as np
import igraph
from igraph import Graph

# Language processing
import nltk
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import string

# Machine learning
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
# library to parse the xml content of the EP full text database
# library doc: https://docs.python.org/3/library/xml.etree.elementtree.html
import xml.etree.ElementTree as ET

# %%
# disable warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Configuration

# %%
class Config:
    """Configuration"""
    
    # Magic numbers
    LAST_YEAR_TO_RECEIVE_CITAITONS = 2018
    PERCENTAGE_TOP_PATENTS = 0.01

    # PASTAT_variables 
    VAR_APPLN_ID = 'appln_id'
    VAR_DOCDC_FAMILY_ID = 'docdb_family_id'
    VAR_CITED_DOCDB_FAM_ID = 'cited_docdb_family_id'
    VAR_APPLN_FILLING_YEAR = 'appln_filing_year'
    VAR_NB_CITING_DOCDB_FAM = 'nb_citing_docdb_fam'
    VAR_EARLIEST_FILLING_DATE = 'earliest_filing_date'
    VAR_EARLIEST_FILING_YEAR = 'earliest_filing_year'

    # Computed variables
    NEW_VAR_CITING_DOCDB_FAM_IDS = 'citing_docdb_families_ids'
    NEW_VAR_NB_CITING_DOCDB_FAM_BY_YEAR = 'nb_citing_docdb_fam_by_year'

# %% [markdown]
# ## Load data

# %% [markdown]
# ### PATSTAT data and EP Full-text data
# * We load the PATSTAT data previously retrieved with the `data_extraction_from_PATSTAT.ipynb` notebook
# * We load the data containing the full-text data for the patents of interest, extracted via the notebook `data_retrieval_from_EP_full_text_database.ipynb`.

# %%
# location of the PATSTAT data previously retrieved with the data_extraction_from_PATSTAT.ipynb notebook
output_files_prefix = "wind_tech_1990_2020_with_publications"
pre = '../data/raw/' + output_files_prefix
suf = '.csv'

# %%
# For convenience, we store all the data retrieved into a single data object.
data = {'_table_main_patent_infos': pd.read_csv(pre + '_table_main_patent_infos' + suf, low_memory=False),
       '_table_cpc': pd.read_csv(pre + '_table_cpc' + suf, low_memory=False), 
       '_table_patentees_info': pd.read_csv(pre + '_table_patentees_info' + suf, low_memory=False),
       '_table_backward_docdb_citations': pd.read_csv(pre + '_table_backward_docdb_citations' + suf, low_memory=False),
       '_table_forward_docdb_citations': pd.read_csv(pre + '_table_forward_docdb_citations' + suf, low_memory=False),
       '_text_data':pd.read_csv('../data/raw/wind_tech_1990_2020_with_publications_full_text.csv', sep = ',')}

# %% [markdown]
# ## Data cleaning

# %%
class DataCleaning:
    """Data cleaning methods"""
    
    def __init__():
        pass
    
    
    def _correct_JP_data(self):
        """Correction for Japanese patent data, in line with the literature"""
        # Do # Update the list of ids
        self = self.__update_patent_fam_ids() # Storing ids and filtering datasets
        return self
    
    
    def _keep_only_EP_patents(self):
        """We filter the data to keep only EU patents (not only EP)"""
        
        # Local variables for simplicity
        df_main = self.data['_table_main_patent_infos']
        condition = df_main[''].isin(Config.EU_authorities)
        df_main = df_main[condition]
        self = self.__update_patent_fam_ids() # Storing ids and filtering datasets
        return self
    
    
    def _normalise(self):
        """Normalisation of the data accross years and sectors, to cater for **patent explosion**"""
        # Do # Update the list of ids
        self = self.__update_patent_fam_ids() # Storing ids and filtering datasets
        return self
    
    
    def _select_one_patent_per_family(self):
        """In order to select only patent of interest, as well as
        saving computationnal power, we select only the earliest patent by
        family"""
        
        # Local variables for simplicity
        df_main = self.data['_table_main_patent_infos']
        df_cpc = self.data['_table_cpc']
        df_patentees = self.data['_table_patentees_info']
        
        # Filtering 
        df_main.sort_values(by = Config.VAR_EARLIEST_FILLING_DATE,inplace = True)
        df_main.drop_duplicates(subset = [Config.VAR_DOCDC_FAMILY_ID],
                                keep = 'first',
                                inplace = True)
        
        # Storing ids and filtering datasets
        self = self.__update_patent_fam_ids()   
        return self
    

    def _select_breakthrough_patents(self):
        """Filtering the data to keep only breakthrough patents"""
        
        # Unpacking some variables for clarity
        X = Config.PERCENTAGE_TOP_PATENTS
        df = self.data['_table_main_patent_infos']
        
        # Selection  of the top patents
        filtered_df = pd.DataFrame()
        for year in df[Config.VAR_EARLIEST_FILING_YEAR].unique().tolist():
            df_year = df[df[Config.VAR_EARLIEST_FILING_YEAR] == year]
            df_year.sort_values(by = Config.VAR_NB_CITING_DOCDB_FAM,
                                ascending = False,
                                inplace = True)
            nb_top_patent_given_year = int(math.ceil(X*len(df_year))) # Needs rounding up
            df_year = df_year.head(nb_top_patent_given_year)
            filtered_df = pd.concat([filtered_df, df_year])
            
        # Update the table and the list of patent/fam ids
        self.data['_table_main_patent_infos'] = filtered_df
        
        # Storing ids and filtering datasets
        self = self.__update_patent_fam_ids()
        return self
    
    
    def __update_patent_fam_ids(self):
        """
        Storing patents ids and family ids and filtering the datasets
        # Filtering the first 3 datasets on the list of patent ids 
        # Filtering the other 2 datasets on the list of family ids
        """
        
        # (1) Update the list of ids (patent ids and family ids)
        df_main = self.data['_table_main_patent_infos']
        self.patent_ids = df_main[Config.VAR_APPLN_ID].unique().tolist()
        self.patent_family_ids = df_main[Config.VAR_DOCDC_FAMILY_ID].unique().tolist()
        
        # (2) Filter the tables according to the new list of patent ids
        def __filter(df, var, list_ids):
            """Code snippet to filter a dataset according to a list of ids"""
            condition = df[var].isin(list_ids)
            return df[condition]
        
        for key in self.data:
            if key in ['_table_main_patent_infos','_table_cpc','_table_patentees_info']:
                self.data[key] = __filter(self.data[key], Config.VAR_APPLN_ID, self.patent_ids)
            elif key in ['_table_backward_docdb_citations','_table_forward_docdb_citations']:
                self.data[key] = __filter(self.data[key], Config.VAR_DOCDC_FAMILY_ID, self.patent_family_ids)
        
        return self

# %% [markdown]
# ## New metrics

# %%
class NewMetrics:
    """Methods to derive new metrics from the data"""
    
    def __init__():
        pass
    
    
    def _get_DOCDB_fam_cites_per_year(self):
        """Adding a variable to keep track of yearly citations by patent family"""
        
        # Unpacking some variables for clarity
        df = self.data['_table_main_patent_infos']
        citations_by_year = Config.NEW_VAR_NB_CITING_DOCDB_FAM_BY_YEAR
        citations_docdb_fam = Config.VAR_NB_CITING_DOCDB_FAM
        year = Config.VAR_APPLN_FILLING_YEAR
        ref_year = Config.LAST_YEAR_TO_RECEIVE_CITAITONS
        
        # Compute the metric
        df[citations_by_year] = df[citations_docdb_fam]/(ref_year-df[year])
        
        # Updating the table
        self.TABLE_ALL_PATENTS_INFO = df 
        return self

# %% [markdown]
# ## Patent object

# %%
# We create a patent object. Since the patent will have a long list of attributes, 
# we stored their attributes in a dictionnary. As a shortcut, we store the main patent key 
# appln_id as an attribute direclty accesible with patent.appln_id.


class Patent:
    
    def __init__(self, appln_id):
        """Setting the patent parameters"""
        
        self.appln_id:int # as a shortcut we  store the main patent key
        self.patent_attributes = {} # Contains the list of the patent's attributes
        
        # Set instance attributes
        self.patent_attributes.update({Config.VAR_APPLN_ID :  appln_id})
        self.appln_id = appln_id

# %% [markdown]
# ## Reshaping to OOP

# %%
# We define a set of methods to reshape the data from the tabular form (as extracted from PATSTAT)
# to an object oriented form, where patents are identified and attributes attributed to them.

class ReshapingToOOP:
    """Methods to assign the data to patent objects"""
    
    def __init__(self):
        pass
    
    
    def _create_patent_objects(self):
        """
        Create a Patent object for each patent id and store them in a list
        """
        self.patent_list = []
        for patent_id in list(self.patent_ids):
            a = Patent(patent_id)
            self.patent_list.append(a)
            
        return self
    
    
    def _assign_data_to_patent_obj(self):
        """
        Once the data has been retrieved from PATSTAT and the patent objects
        have been created, we assign the data to the Patent objects
        """
        
        def __snippet_store_patent_attributes(table):
            """
            Code snippet to dynamically store attributes 
            from a Pandas table in a dictionnary
            # If a value has several values, then ts stored in a list
            """
            a = {}
            for col in list(table):
                key = col
                value = table[col].unique().tolist()#[0]
                value = [x for x in value if (x == x)!=False] # new line
                if len(value) == 1:
                    value = value[0]
                a[key] = value
            return a
        
        # Unpacking some variables
        df_main = self.data['_table_main_patent_infos']
        df_cpc = self.data['_table_cpc']
        df_patentee = self.data['_table_patentees_info']
        df_bwd = self.data['_table_backward_docdb_citations']
        df_fwd = self.data['_table_forward_docdb_citations']
        
        # (1) Assigning the data contained in the main table to the patent
        # We merge backward citation data to the main table (on family id)
        key = Config.VAR_DOCDC_FAMILY_ID
        df_main = pd.merge(df_main, df_bwd,how = 'left',left_on = key,right_on = key)
        
        for patent in self.patent_list:                
            for df in [df_main, df_cpc, df_patentee]:  
                patent_table = df[df[Config.VAR_APPLN_ID]==patent.appln_id]
                d = __snippet_store_patent_attributes(table = patent_table)
                patent.patent_attributes.update(d)
        
        # (2) Assigning forward citations to the patents      
        df_fwd.columns = ['A','B','C'] # Random column names
        for patent in self.patent_list:
            patent_fam_table = df_fwd[df_fwd['A']==patent.patent_attributes[Config.VAR_DOCDC_FAMILY_ID]]
            citing_fam = patent_fam_table['B'].unique().tolist()
            patent.patent_attributes.update({Config.NEW_VAR_CITING_DOCDB_FAM_IDS :citing_fam})
            
        return self

# %% [markdown]
# ## Get citations
# We use the similarity measure to link the patents in the network. We use direct and indirect citation links: 􏰀
# * Direct backwards citation (at the patent family level); 􏰀
# * Co-citations (CC);
# * Biographic coupling (BC);
# * Longitudinal coupling (LC).

# %%
class GetCitations:
    """Methods to compute direct and indirect (BC, CC, LC) citations between the patents"""
        
    def _get_direct_citations(self):
        """Get direct backwards citations (at the level of the family level)"""
        
        # Unpacking some varibles for clarity
        fam = Config.VAR_DOCDC_FAMILY_ID
        cited_fam = Config.VAR_CITED_DOCDB_FAM_ID
            
        # (1) If a patent cites only one family
        list1 = [(x,y) for x in self.patent_list for y in self.patent_list \
                 if y.patent_attributes[fam] == x.patent_attributes[cited_fam]]
        
        # (2) If the patent cites several families (then stored as list)
        list2 = [(x,y) for x in self.patent_list for y in self.patent_list \
                 if type(x.patent_attributes[cited_fam]) ==list \
                 if y.patent_attributes[fam] in x.patent_attributes[cited_fam]]
        
        # Concatenating the two lists to have the direct citations
        self.direct_citations = list1 + list2
        return self
        
        
    def _get_BC_citations(self):
        """
        # (1) Bibliographic coupling occurs when two works reference a common third work
        # (2) The produced list is non directed.
        # (3) Can be optimised
        """
            
        # Definition of variables
        BC = []
        a = self.patent_list
        all_patent_pairs = [(a[p1], a[p2]) for p1 in range(len(a)) for p2 in range(p1+1,len(a))]

        # Computing BC by looping over all pairs of patents
        for patent_1, patent_2 in all_patent_pairs:
            list_citing_1 = patent_1.patent_attributes[Config.NEW_VAR_CITING_DOCDB_FAM_IDS]
            list_citing_2 = patent_2.patent_attributes[Config.NEW_VAR_CITING_DOCDB_FAM_IDS]
            common_elements = [x for x in list_citing_1 if x in list_citing_2]
            if len(common_elements)>0:
                BC.append((patent_1, patent_2))
            
        # Removing duplicated items in the list
        self.BC = list(set(BC)) 
        return self
        
        
    def _get_CC_citations(self):
        """
        # (1) Co-citation is defined as the frequency with which two documents are cited together
        by other documents. If at least one other document cites two documents in common these documents
        are said to be co-cited
        # (2) The produced list is non directed
        """
        CC = []
            
        # Definition of all patent pairs
        a = self.patent_list
        all_patent_pairs = [(a[p1], a[p2]) for p1 in range(len(a)) for p2 in range(p1+1,len(a))]
            
        # Definition of the search algorithm
        for patent in self.patent_list:
            a = patent.patent_attributes[Config.VAR_CITED_DOCDB_FAM_ID]
            if type(a)==list:
                if len(a)>1:
                    all_cited_patent_pairs = [(a[p1], a[p2]) \
                                              for p1 in range(len(a)) \
                                              for p2 in range(p1+1,len(a))]
                    for pair in all_cited_patent_pairs:
                        CC.append(pair)
        
        pairs = list(set(CC)) 
        
        CC = []
        for pair in pairs:
            patent1 = [patent \
                       for patent in self.patent_list \
                       if patent.patent_attributes[Config.VAR_DOCDC_FAMILY_ID] == pair[0]]
            patent2 = [patent \
                       for patent in self.patent_list \
                       if patent.patent_attributes[Config.VAR_DOCDC_FAMILY_ID] == pair[1]]

            if len(patent1)>0:
                patent1 = patent1[0]
            else: patent1=np.nan

            if len(patent2)>0:
                patent2 = patent2[0]
            else: patent2=np.nan

            pair = (patent1, patent2)
            CC.append(pair)

        self.CC = [pair for pair in CC if (pair[0]==pair[0]) & (pair[1] == pair[1])]
        return self
     
        
    def _get_LC_citations(self):
        """
        # (1) LC (longitudinal coupling). A cites a document that cites B
        # (2) The produced list IS directed 
        # (3) Can be optimised
        """          
        LC = []
            
        # Identifying all patents cited by a given patent A
        for patent_A in self.patent_list:
            cited_fam = patent_A.patent_attributes[Config.VAR_CITED_DOCDB_FAM_ID]
            if type(cited_fam)==float:
                    cited_fam = []
                    cited_fam.append(patent_A.patent_attributes[Config.VAR_CITED_DOCDB_FAM_ID])
            cited_patents = [patent \
                             for patent in self.patent_list \
                             if patent.patent_attributes[Config.VAR_DOCDC_FAMILY_ID] in cited_fam]
                
            # Identifying all patents cited by a patent cited by patent A
            for cited_patent in cited_patents:
                cited_fam = cited_patent.patent_attributes[Config.VAR_CITED_DOCDB_FAM_ID]
                if type(cited_fam)==float:
                    cited_fam = []
                    cited_fam.append(cited_patent.patent_attributes[Config.VAR_CITED_DOCDB_FAM_ID])
                cited_cited_patents = [patent \
                                       for patent in self.patent_list \
                                       if patent.patent_attributes[Config.VAR_DOCDC_FAMILY_ID] in cited_fam]
                    
                # Adding the pairs in the LC list
                for patent_B in cited_cited_patents:
                    LC.append((patent_A, patent_B))
                    
        # Removing duplicated items in the LC list
        self.LC = list(set(LC)) 
        return self

# %% [markdown]
# ## Retriving the full text data for the patents of interest

# %%
class RetrieveFullTextData:
    """
    Methods to retrieve the full text data to the selected patents.
    """
    
    def __init__():
        pass
    
    
    def _assign_full_text_to_patents(self):
        """
        For each patent contained in the model, assigns in the patent attributes
        under the 'full_text' entry a dataframe containing all the text of this 
        patent, in raw format
        """
        
        lista = [str(x) for x in list(self.data['_text_data']['publication_number'])]
        df = self.data['_text_data']
        cols = list(df)

        for patent in self.patent_list:
            if patent.patent_attributes['publn_nr'] in lista:
                data = df[df['publication_number'] == int(patent.patent_attributes['publn_nr'])]
                patent.patent_attributes['full_text'] = data
            else:
                patent.patent_attributes['full_text'] = pd.DataFrame(columns=cols)
        return self
           
        
    @staticmethod    
    def _translate(text_to_translate, source_language = False, target_language = 'en'):
        """Machine translation using the Google translate API"""

        # initialise the translator object (see the googletrans API docs)
        translator = Translator()
        # behaviour of the function if the input language is known
        if source_language != "False":
            translatedText = translator.translate(text_to_translate, src=source_language, dest=target_language)
        # if the language of the input is not known
        else: 
            translatedText = translator.translate(text_to_translate, dest=target_language)
        return translatedText.text

    
    @staticmethod 
    def _get_text_claims(data_patent_text):
        """For a given dataframe coming from the EP full-text database, returns
        a list of its claim"""

        ## data manipulation

        # nickname 
        data = data_patent_text
        # select only the claims in the dataframe
        data = data[data['text_type']=='CLAIM']
        # sort by data
        data = data.sort_values(by = 'publication_date', ascending = False)
        # keep only most recent claims by language
        data.drop_duplicates(subset = ['language_text_component','text_type'], inplace = True)
        # keep languages according to the other EN, DE, FR, other ('xx') (for best consistency of the translating)
        data['language_text_component'] = pd.Categorical(data['language_text_component'] , categories=["en","de","fr","xx"], ordered=True)
        data = data.sort_values(by = 'language_text_component')
        data.drop_duplicates(subset = ['text_type'], inplace = True)

        # if the data contains no claims then the data selected is empty
        if len(data)==0:
            return ['Unavailable']

        else:

            # store the language at this point for translation at the end
            language = data.iloc[0]['language_text_component']
            # selection of the field of the pandas dataframe which contains the claims texts
            text_xml = data.iloc[0]['text']

            ## Process the xml to get the raw text

            # modifying the claim to be processed as a real xml
            text_xml_modified = "<data>" + text_xml + '</data>'
            # we parse it with the ElementTree XML API¶
            root = ET.fromstring(text_xml_modified)
            # and this is how we access the text of the claims
            claims = root.findall("./claim/claim-text")
            # we store the claims in a list
            claims_text = [claim.text for claim in claims]

            ## Translate if the claims are not in EN
            if language =='en':
                pass
            elif language == 'de':
                claims_text = [RetrieveFullTextData.translate(text, 'de', 'en') for text in claims_text]
            elif language == 'fr':
                claims_text = [RetrieveFullTextData.translate(text, 'fr', 'en') for text in claims_text]
            elif language == 'xx':
                claims_text = [RetrieveFullTextData.translate(text, False, 'en') for text in claims_text]
            else:
                claims_text = [RetrieveFullTextData.translate(text, False, 'en') for text in claims_text]

            return claims_text


    def _attribute_claims(self):
        """For each patent, uses the _get_text_claims function to store the claims text in the object"""
        for patent in self.patent_list:
            patent.patent_attributes['full_text_claims'] = RetrieveFullTextData._get_text_claims(patent.patent_attributes['full_text'])
        return self

# %% [markdown]
# ## Text processing (work in progress)
#
# - stemming
# - vectorisation with TF-IDF
# - measure cosine similarity

# %%
class CustomStemmer(BaseEstimator, TransformerMixin):
    """We overwrite the Sklearn BaseEstimator class in order to have more control on the 
    text data preprocessing"""
    
    def __init__(self, stemmer_type):
        """We can use different types of stemmer"""
        
        self.tokenizer = RegexpTokenizer("(?u)\\b[\\w-]+\\b")
        self.stemmer_type = stemmer_type
        
        if stemmer_type == 'snowball':
            self.stemmer = SnowballStemmer("english")
    
    def fit(self, documents, labels = None):
        """Overwritten for the sake of completeness, does not perform any action"""
        return self
    
    def transform(self, documents):
        """Returns a stemmed version of the documents, using the Porter algorithm (snowball)
        and removing English stop words"""
        
        if self.stemmer_type!='no':
            documents = documents.apply(self.tokenizer.tokenize)

            def snowball(x):
                liste = [self.stemmer.stem(y) for y in x]
                return liste

            documents = documents.apply(snowball)
            documents = [' '.join(docs) for docs in documents]
        
        return documents

# %%
class CustomVectorizer(BaseEstimator, TransformerMixin):
    """We overwrite the Sklearn BaseEstimator class in order to have more control on the vectorisation"""
    
    def __init__(self, vectorizer_type):
        """Two possibilities here: count and tfidf. More can be added if neccessary"""
        
        if vectorizer_type == 'count':
            self.vectorizer = CountVectorizer(binary=True)
    
        if vectorizer_type == 'tfidf':
            self.vectorizer = TfidfVectorizer(stop_words='english')
    
    def fit(self, documents, labels = None):
        """Does not perform any action"""
        return self
    
    def transform(self, documents):
        """Return a numpy arraw - the feature space"""
        freqs = self.vectorizer.fit_transform(documents)
        return [freq.toarray()[0] for freq in freqs]

# %%
class TextProcessing:
    """
    Methods for text analysis and similarity measures, using the 2 classes above.
    """
    
    def _index_patents(self):
        """We create an index of patents, in order to be able to process all the text together in
        the following text processing steps and still be able to access individual patent text data"""
        
        self.dict_patents_indexes = {k: v for v, k in enumerate(self.patent_list)}
        return self
    
    
    def _store_vocabulary(self):
        """Store all the vocabulary contained in the patents in a Panda series called 'corpus' """
        
        # create an empty list and fill it with the claim text of each patent in a separate entry
        l = []
        for patent in self.patent_list:
            l.append(patent.patent_attributes['full_text_claims'])
        # flatten the nested list by joining the sentences/claims together in a single sentence
        # for each patent / except if the text is unavailable
        l = [' '.join(element) for element in l if isinstance(element, str)==False]
        # reshape as a single Pandas serie and store in the corpus
        self.corpus = pd.DataFrame(l, columns=['text']).pop('text')
        return self
    
    def _stemming(self):
        """Reducing words to their stem word (semantic root), and remove the English stop words"""
        
        stemmer = CustomStemmer('snowball')
        self.corpus_stemmed = stemmer.transform(self.corpus)
        
        ### HERE FOR ALL THE PATENTS STORE THE STEMMED TEXT IN THE ATTRIBUTES
        return self
    
    def _vectorize(self):
        """Vectorise the patents in a high dimention space (returns a list)"""
        
        custom_vectorizer = CustomVectorizer('tfidf')
        self.feature_space = custom_vectorizer.fit_transform(self.corpus_stemmed)
        
        # iterating through all pairs of patents to get their pairwise similarity
        for patent in model.patent_list:
            index = model.dict_patents_indexes[patent]
            patent.patent_attributes['stemmed text'] = model.corpus_stemmed[index]
        return self

    
    def _compute_pairwise_similarities(self):
        """returns a numpy.ndarray containing all pairwise similarities between patents"""
        
        # https://stackoverflow.com/questions/12118720/python-tf-idf-cosine-to-find-document-similarity
        # To compute the cosine distance of the first doc to all the others 
        from sklearn.metrics.pairwise import linear_kernel
        # in this case linear_kernel is equivalent to cosine_similarity because the TfidfVectorizer produces normalized vectors.
        # returs an array with all pairwise similarities!
        self.cosine_similarities = linear_kernel(self.feature_space, self.feature_space)
        return self
    
    
    def _similarity(self, patent1, patent2):
        """Measure the similiarity between a pair of linked patents pair = (patent1, patent2)"""
        i = self.dict_patents_indexes[patent1]
        j = self.dict_patents_indexes[patent2]
        return self.cosine_similarities[i,j]

# %% [markdown]
# ## Building the nlp-based patent network

# %%
class BuildNetwork():
    """Builds a weighted network based on backwards citations and text similarity"""
    
    def _create_network(self):
        """Create the weighted and undirected network with igraph"""

        def filter_symmetric_duplicates(l:list):
            """Code snippet to filter symmetric duplicates in a list of tuples
            Eg [(1,2), (2,1)] -> [(1,2)]"""
            seen = []
            for pair in l:
                if pair in seen:
                    l.remove(pair)
                seen.append(tuple(reversed(pair)))
            return l
        
        # defining all possible links between any pair of patents
        links = self.direct_citations + self.CC + self.BC + self.LC
        
        # definition of the links
        links = filter_symmetric_duplicates(links)
        weighted_links = [(p1, p2, TextProcessing._similarity(self, p1, p2)) for (p1, p2) in links]
        
        # creation of the graph
        self.graph = Graph.TupleList(weighted_links, weights=True)
        
        return self

# %% [markdown]
# ## Summary statistics (work in progress)

# %%
class SummaryStatistics:
    """Summary statistics for the data section"""
    # Can also help comparing before data cleaning and after!
    
    def _print_nb_patents(self):
        """Printing info"""
        print('..Nb of patents:',len(self.data['_table_main_patent_infos']\
                                     [Config.VAR_APPLN_ID].unique().tolist()))

# %% [markdown]
# ## Visualisation (work in progress)

# %%
class Visualisation:
    """Visualisation methods"""
    
    def _draw_graph_with_communities(self):
        comms = model.graph.community_multilevel()
        display(igraph.plot(comms, mark_groups = True))

# %% [markdown]
# ## Core modelling

# %%
class Model(Config, DataCleaning, NewMetrics, ReshapingToOOP, GetCitations, RetrieveFullTextData,
            TextProcessing, BuildNetwork, SummaryStatistics, Visualisation):
    """
    Creation of a model which inherits several building blocks
    """
    
    # Attributes of the model
    
    def __init__(self):
        
        data: dict # datasets
        patent_list: list # patent objects
        dict_patents_indexes: dict # mapping of patents objects and their indexes
        patent_ids: list # list of patent ids contained in the model
        patent_family_ids: list # list of DOCDB family ids contained in the model
        direct_citations: list # directed list of simple citations
        CC: list # undirected list of co-citations
        BC: list # undirected list of bibliographical coupling
        LC: list # directed list of longitudinal citations
        corpus: pandas.core.series.Series # contains all claim text of each patent (raw)
        corpus_stemmed: pandas.core.series.Series # contains all claim text of each patent (stemmed)
        feature_space: list # the feature space, the high dimension representation of the text data
        cosine_similarities: numpy.ndarray # contains all the pairwise similarities between patents
        graph: igraph.Graph # Igraph network 
        
    
    def _input_data(self, data):
        """Getting the data in the model"""
        self.data = data
    
    
    def _compute_new_metrics(self):
        """Adding new variables in the dataset"""
        self = NewMetrics._get_DOCDB_fam_cites_per_year(self)  
    
    
    def _data_cleaning(self):
        """Data cleaning using the DataCleaning class methods"""
        self = DataCleaning._correct_JP_data(self)
        self = DataCleaning._normalise(self)
        self = DataCleaning._select_one_patent_per_family(self)
        self = DataCleaning._select_breakthrough_patents(self)
    
    
    def _fit_to_object_oriented_design(self):
        """We reshape the data from a tabular form to an object oriented form"""
        self = ReshapingToOOP._create_patent_objects(self)
        self = ReshapingToOOP._assign_data_to_patent_obj(self)  
   

    def _get_citations(self):
        """Identify direct and indirect citations that link the patents"""
        self = GetCitations._get_direct_citations(self)
        self = GetCitations._get_CC_citations(self)
        self = GetCitations._get_BC_citations(self)
        self = GetCitations._get_LC_citations(self)
        
    
    def _get_full_text(self):
        """Retrieve the full text data corresponding to the patents in the model, 
        extract the claims and attribute them to the patent objects"""
        self = RetrieveFullTextData._assign_full_text_to_patents(self)
        self = RetrieveFullTextData._attribute_claims(self)
    
    
    def _text_preprocessing(self):
        """Computing text similarities between linked patents
        
        # 1. index all the patents in the 'dict_patents_indexes' dictionnary
        # 2. get all the vocabulary stored in a single Pandas serie
        # 3. text preprocessing
        # 4. vectorisation and create the feature space 
        # 5. compute the array of all pairwise similarities from the feature space
        """
        self = TextProcessing._index_patents(self)
        self = TextProcessing._store_vocabulary(self)
        self = TextProcessing._stemming(self)
        self = TextProcessing._vectorize(self)
        self = TextProcessing._compute_pairwise_similarities(self)
     
        
    def _build_patent_network(self):
        """We build the patent network (weighted directed graph)"""
        self = BuildNetwork._create_network(self)
    
    
    def _visualise(self):
        """Plot"""
        self = Visualisation._draw_graph_with_communities(self)

# %% [markdown]
# ## Results

# %%
# instantiation of the model
model = Model()
# fitting the model to the data
model._input_data(data)
# new metrics
model._compute_new_metrics()
# data cleaning
model._data_cleaning()
# reshape in an OOP manner before building the network
model._fit_to_object_oriented_design()

# %%
# retrieving all types of citations
model._get_citations()

# %%
# Search in the full text database the patents of interest
model._get_full_text()

# %%
# Text preprocessing, construction of the feature space and computation of all pairwise similarities
model._text_preprocessing()

# %%
# builing the NLP-based patent network
model._build_patent_network()

# %%
# plot a visualisation
model._visualise()


### Les liens restent les mêmes sur la visualisation (puisqu'ils sont filtrés par citations etc,
# alors qu'il faudrait que les clusters prennent en compte également la qualité (weight) du lien!

# %%
model._print_nb_patents()
# Out:
# ..Nb of patents: 614

# %% [markdown]
# # Prototyping

# %%
# Verification of the contains of the patent full_text_claims
for patent in model.patent_list:
    print(patent.patent_attributes['full_text_claims'])
# Out:
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['An apparatus for use with an auditory prosthesis system (100), the apparatus comprising:', 'The apparatus of claim 1, wherein the apparatus (202) is configured to receive from the sound processor module (102) by way of the second connector port (404-2), a DC power signal configured to selectively provide power to the auxiliary audio input device (204, 314) by way of the connector port (404-1) and the telecoil (402), and wherein the apparatus further comprises:', 'The apparatus of claim 2, wherein:', 'The apparatus of claim 1, wherein the switch (324) is configured to selectively enable the auxiliary audio input device (204, 314) and the telecoil (402) by selectively providing operating power to the auxiliary audio input device by way of the connector port and the telecoil.', 'The apparatus of claim 1, wherein at least a portion of the switch (324) is disposed on an outer surface of the housing (320) and is configured to be selectively positioned within one of the three positions by a user.', 'The apparatus of claim 1, wherein the auxiliary audio input device (204) comprises an auxiliary microphone (314).', 'The apparatus of claim 1, wherein the housing (320) is configured to be worn behind an ear of a user.', 'A system comprising the apparatus (202) of claim 1 and an auxiliary audio input device (204, 314), the system further comprising:', 'The system of claim 8, wherein the headpiece (104) comprises an additional microphone (114) configured to detect one or more of the audio signals when the auxiliary microphone (314) is disabled.', 'A method comprising:']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Wind turbine blade comprising a first (1) and a second (2) electric conductor extending in the longitudinal direction of the blade (25), one or more electric heating elements (4) for heating the surface of the blade, said heating elements (4) being connected to the first (1) and the second (2) conductor, ', 'Wind turbine blade as claimed in claim 1, ', 'Wind turbine blade as claimed in one or more of the preceding claims, ', 'Wind turbine blade as claimed in one or more of the preceding claims, ', 'Wind turbine blade as claimed in one or more of the preceding claims, ', 'Wind turbine blade as claimed in one or more of the preceding claims, ', 'Wind turbine blade as claimed in one or more of the preceding claims, ', 'Wind turbine blade as claimed in one or more of the preceding claims, ']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A control system for a wind power plant (WPP), ', 'The control system according to claim 1, ', 'The control system according to claim 1, ', 'The control system according to one of the preceding claims, ', 'The control system according to one of the preceding claims, ', 'The control system according to one of the preceding claims, ', 'The control system according to one of the preceding claims, ', 'The control system according to one of the preceding claims, ', 'The control system according to one of the preceding claims, ', 'The control system according to one of the preceding claims, ', 'The control system according to one of the preceding claims, ', 'The control system according to one of the preceding claims, ']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A servo control apparatus comprising:', 'The servo control apparatus specified in claim 1, wherein one of the plurality of servo control circuits (2a, 2b, 2c, 2d) is defined as the master servo control circuit, and the other servo control circuits are defined as the slave servo control circuits, whereby the slave servo amplifiers receive a command signal normally input from the master servo controller, and wherein, if an abnormality occurs in the master servo control circuit, a command signal selector (21) switches so as to input a command signal from a slave servo controller.']
# ['Unavailable']
# ['Unavailable']
# ['A blade for a wind turbine, wherein at least a third of the total length, measured from the tip to hub, of said blade comprises a layer (1,2) along an outer periphery of the cross-section of said blade, ', 'A blade according to claim 1, wherein the strips of the outer layer (1,2) are jointed by means of resin infusion.', 'A blade according to claim 2, wherein the strips of the outer layer (1,2) are jointed by means of vacuum infusion of a resin.', 'A blade according to any of claims 1-3, wherein at least some of the pre-fabricated pultruded strips (2) are constituted by hollow tubes formed from a fibrous composite material.', 'A blade according to claim 4, wherein the pultruded strips (2) have a pultrusion direction substantially aligned with a longitudinal direction of the blade.', 'A blade according to any of claims 4-5, wherein the fibrous composite material comprises a fibre volume fraction from 50 percent to 90 percent.', 'A blade according to claims 6, wherein the fibrous composite material comprises a fibre volume fraction of from 60 percent to 80 percent.', 'A blade according to any of claims 4-6, wherein the fibrous composite material comprises a carbon fibre volume fraction from 50 percent to 90 percent', 'A blade according to claims 8, wherein the fibrous composite material comprises a fibre volume fraction of from 60 percent to 80 percent.', 'A blade according to any of the preceding claims, wherein the layer (1,2) at least partly is constituted by a number of strips made from a wooden material arranged in a sequence along the outer periphery.', 'A blade according to claim 10, wherein the wooden material is plywood.', 'A blade according to claim 10, wherein the wooden material is comprised by wooden fibres held in a cured resin.', 'A blade according to any of claims 10-12, wherein the layer (1,2) at least partly is constituted by strips of a wooden material and strips of a fibrous composite material in a sequence along the outer periphery.', 'A blade according to claim 13, wherein said sequence is an alternating sequence of strips of a wooden material and strips of a fibrous composite material', 'A blade according to any of the preceding claims, wherein said layer is enclosed in an outer shell and an inner shell made from a fibrous composite material.', 'A blade according to any of the preceding claims, wherein load measuring fibres is enclosed in either one or both of the outer shell and the inner shell.', 'A blade according to claim 16, wherein the load measuring fibres are optical fibres being additional to, alternatively being substitute to, the reinforcing fibres.', 'A blade according to claim 16, wherein the load measuring fibres are carbon fibres being additional to, alternatively being substitute to, the reinforcing fibres.', 'A blade according to any of the preceding claims, wherein lightning protection means comprising lightning attractors are incorporated into either one or both of the shells.', 'A blade according to claim 19, where the lightning attractors are connected to a width of metal mesh (11) or similar material extending over the fibre reinforced area of the shells.', 'A blade according to any of the preceding claims, wherein a radio frequency absorption medium is incorporated into either one or both of the shells.', 'Method for manufacturing a shell for a blade according to any of the claims 1-21, said shell comprising a layer material arranged along an outer periphery of the cross-section of the shell, said layer comprising pre-fabricated strips, and said method involving the following steps:']
# ['Unavailable']
# ['Unavailable']
# ['A method for improving the efficiency of a wind turbine rotor, comprising the furnishing a serrated panel at a trailing edge (3) on each of the wind turbine rotor blades (1) of the wind turbine rotor, each of said panels having a plurality of span-wise, periodic indentations (15), such that the serrations extend from the trailing edge into airflow behind the trailing edge on each wind turbine rotor blade of the wind turbine rotor, wherein the serrations are provided at an angle different from 0 degrees relative to the blade chord, ', 'A method for improving the efficiency of a wind turbine rotor according to claim 1, wherein the serrations (15) are provided as a retrofit of an existing wind turbine rotor by the attachment of a serrated panel to the surface of the wind turbine blade near the existing trailing edge and where the serrations extend from the existing trailing edge (3) of the blade into the airflow behind the existing trailing edge.', 'A method for improving the efficiency of a wind turbine rotor according to claim 1, wherein the serrations (15) are provided as part of a new blade.', 'A method for improving the efficiency of a wind turbine rotor according to any of the previous claims, wherein the serrations (15) are provided over a span wise extent of the trailing edge having a length of between 30 and 100 percent of the radius of the blade.', 'A method for improving the efficiency of a wind turbine rotor according to any of the previous claims, wherein the serrations (15) are provided in the form of saw teeth having approximately 60 degrees included angles between adjacent vertices.', 'An apparatus for improving the efficiency of a wind turbine rotor, comprising a serrated panel connected to each wind turbine rotor blade, an upper and a lower surface on each panel, a plurality of span-wise, periodic indentions (15) on each panel, means for connecting the serrated panel to a trailing edge (3) on each of the wind turbine rotor blades of the wind turbine rotor such that the serrated panel extends from the trailing edge into airflow behind the trailing edge on each wind turbine rotor blade of the wind turbine rotor, wherein the serrations on each wind turbine rotor blade having an angle different from 0 degrees relative to a mounting surface on each of the wind turbine rotor blades of the wind turbine rotor, ', 'An apparatus for improving the efficiency of a wind turbine rotor according to claim 6, wherein the serrations (15) have a span wise extent of the trailing edge having a length of between 30 and 100 percent of the radius of the blade.', 'An apparatus for improving the efficiency of a wind turbine rotor according to any of claims 6 or 7, wherein the serrations (15) have the form of saw teeth having approximately 60 degrees included angles between adjacent vertices.', 'An apparatus for improving the efficiency of a wind turbine rotor according to any of claims 6-8, wherein the part of the serrated panel serrations (15) have the form of saw teeth having approximately 60 degrees included angles between adjacent vertices.']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['An electrical machine arrangement comprising:', 'An arrangement as claimed in claim 1 wherein the first plurality of permanent magnets (30,32) are attached to a soft-ferromagnetic support (16) and the second plurality of permanent magnets (32,30) are supported without attachment to soft-ferromagnetic material (16).', 'An arrangement as claimed in claim 2, wherein the second plurality of permanent magnets (32,30) are supported by a magnetically transparent material.', 'An arrangement as claimed in any preceding claim, wherein the second plurality of permanent magnets (32,30) are arranged in a cylinder (40) with an air gap of 3-5 mm between the stator (42) and the cylinder (40).', 'An arrangement as claimed in any preceding claim, comprising a first support (16A,16B,16C) supporting the first plurality of permanent magnets (30,32) at a first fixed radius from the axis (34) and a second support (41,43) supporting the second plurality of permanent magnets (32,30) at a second fixed radius from the axis (34), wherein the first and second supports (16A,16B,16C,41,43) are coupled to a shaft (54) by a plurality of bearings (58) such that the first and second supports rotate independently about the shaft (54) on the plurality of bearings (58), said shaft extending from an end of the stator (42) along the axis (34).', 'An arrangement as claimed in claim 5, wherein the first support (16A,16B,16C) rotates relative to a housing (12) on large bearings (14).', 'An arrangement as claimed in any preceding claim wherein the support (41,43) for the second plurality of permanent magnets (32,30) provides for air circulation (45,43,47,51) over the stator (42) when in use.', 'An arrangement as claimed in any preceding claim wherein the interference means (36) comprises a plurality of iron pole pieces evenly distributed at a fixed radius about the axis.', 'A wind turbine generator (2) comprising an arrangement as claimed in any preceding claim.', 'A wind turbine generator (2) comprising an arrangement as claimed in claim 6, wherein the large bearings (14) support the turbine rotor shaft.', 'A method of generating electricity comprising the steps of:', 'A method of transducing time varying electrical energy into the rotation of a motor shaft (54), comprising the steps of:', 'A method as claimed in claim 12 wherein the second plurality of permanent magnets (32) is attached to the motor shaft (54).']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Electrode sensor for electrical impedance tomography comprising', 'Electrode sensor in accordance with claim 1 ', 'Electrode sensor in accordance with any one of the preceding claims ', 'Electrode sensor in accordance with any one of the preceding claims ', 'Electrode sensor in accordance with any one of the preceding claims ', 'Electrode sensor in accordance with any one of the preceding claims ', 'Electrode sensor in accordance with any one of the preceding claims ', 'Electrode sensor in accordance with any one of the preceding claims 1-6 ', 'Electrode sensor in accordance with any one of the preceding claims ', 'Electrode sensor in accordance with any one of the preceding claims ', 'Electrode sensor in accordance with any one of the preceding claims ', 'Electrode sensor in accordance with any one of the preceding claims ', "Method of manufacturing an electrode sensor for electrical impedance tomography, comprising an array of spaced apart individual contact elements (3, 15, 27, 27', 41) and an interface structure (1, 9, 19, 19', 30, 35, 43) for forming contact between said contact elements and the skin, comprising the steps of:", 'Method in accordance with claim 13 ', 'Method in accordance with any one of the preceding claims 13-15 ', 'Use of the electrode sensor according to any one of claims 1 to 12 for medical monitoring.']
# ['Method for generating a representation of a finger print minutiae information comprising the steps of:', 'Method according to claim 1, wherein said coordinate system is ', 'Method according to claim 1 and 2, wherein said sampled function values are ', 'Method according to claim 1, ', 'Method according to claim 4, ', 'Method according to claim 5, wherein said combination of said plurality of feature vectors is a linear combination of the individual vectors.', 'Method according to any one of the preceding claims, wherein the said reference point P is at least one or a group of', 'Method according to any one of the preceding claims, wherein said minutiae information comprises at least one or more of', 'Method according to any one of the preceding claims, wherein the minutia are grouped into a plurality of distinct sets, and the contribution of the plurality of distinct sets are merged into independent feature vectors or combinations thereof.', 'Method according to claim 9, wherein the clustering is achieved according to their radial distance from the reference stable point', 'A system for generating a representation of minutiae locations in a finger print comprising']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Method for anonymously associating measurement device measurements to a source, the method is ', 'Method according to claim 1 wherein the comparing of step e) further comprises setting a threshold (14) for the values of each of the metadata to be compared.', 'Method according to any one of the previous claims wherein the result of the comparison of step e) refers to one specific metadata obtained by a direct match (6) from both the first and the second set of metadata.', 'Method according to any one of previous claims wherein the comparing of step e) further comprises inference rules (10) relating (11,12,13) at least two specific metadata.', 'Method according to any one of previous claims wherein the metadata taken for the comparison of step e) are combined in groups of at least two elements.', 'Method according to claim 5 further comprising refining the comparison of step e) by increasing iteratively (9) the number of metadata taken to be compared.', 'Method according to any one of previous claims wherein the communication device associated to the user and the measurement device broadcast an identifier as part of the metadata and they wait until recognizing the identifier broadcast by the other before sending anything to the server.', 'Method according to any one of previous claims wherein the metadata are selected from the following list: time, date, serial number, frequency of use, environmental light, environmental temperature, pressure and movements over a screen, location, data from networks at range or any other data gathered by both the measurement device and the communication device associated to the source.', 'Method according to any one of the previous claims wherein the measurement devices comprises health monitoring devices.', 'Method according to any one of previous claims wherein the measurement devices comprises sensors for tracking deliveries, monitoring a fleet of vehicles or sensors for measuring affluence/traffic of certain locations.', 'Method according to any one of previous claims wherein the communication device associated to the source is a portable computing device with communication capabilities as a mobile phone or a tablet.', 'Method according to any one of previous claims wherein the comparing of step e) further comprises logic to compare non-numerical metadata.', 'System for anonymously associating measurement device measurements to a source ID, the system being ', 'Server for anonymously associating measurement device measurements to a source ID, the server being ', 'Computer program product comprising computer program code adapted to perform the method according to any of the claims 1-12 when said program code is executed on a computer, a digital signal processor, a field-programmable gate array, an application-specific integrated circuit, a micro-processor, a micro-controller, or any other form of programmable hardware.']
# ['A computer-implemented method for generating a 3-dimensional representation of a tunnel, the method comprising the steps of:', 'The method for generating a 3-dimensional representation of a tunnel according to claim 1, wherein each tunnel wall further contains, at its upper end, a curved surface, the curved surfaces of the left and right tunnel wall building a tunnel ceiling.', 'The method for generating a 3-dimensional representation of a tunnel according to claim 1 or 2, wherein the predefined patterns (13) contain an entrance and/or exit portal of the tunnel, the 3-dimensional representation of the tunnel being generated using the entrance and/or exit portal.', 'The method for generating a 3-dimensional representation of a tunnel according to claim 1, wherein the 3-dimensional tunnel body (20) further includes a tunnel ceiling.', 'The method for generating a 3-dimensional representation of a tunnel according to claim 1 or 4, wherein the position of the tunnel body (20) below the surface of the Earth is determined by elevation data of a tunnel entrance and of a tunnel exit.', 'The method for generating a 3-dimensional representation of a tunnel according to any one of the preceding claims, further comprising the step of identifying the right and left tunnel wall for each driving direction in the tunnel and storing the identified left and right tunnel walls for each driving direction in the 3-dimensional representation of the tunnel.', 'A system configured to generate a 3 dimensional representation of a tunnel, the system comprising:', 'The system configured to generate a 3-dimensional representation of a tunnel according to claim 7, wherein the data processing unit (14) is configured to embed the tunnel body below the surface of the Earth in such a way that the position of the tunnel body (20) below the surface of the Earth is determined by elevation data of a tunnel entrance and of a tunnel exit.', 'The system configured to generate a 3-dimensional representation of a tunnel according to claim 7 or 8, wherein the data processing unit (14) is configured to identify the right and left tunnel wall for each driving direction in the tunnel and configured to store the identified left and right tunnel walls for each driving direction in the 3-dimensional representation of the tunnel.']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A flexible display device (100) comprising:', 'The flexible display device (100) as claimed in claim 1, wherein the controller (130) changes the screen so that an object displayed in the user grip area in the screen is moved to another area.', 'The flexible display device (100) as claimed in claim 2, wherein the controller (130) expresses an animation effect of pushing the object by the user grip manipulation and gradually moving the object to the other area.', 'The flexible display device (100) as claimed in claim 1, wherein in response to the rolling state being released so that at least part of the display is in a flat state, the controller (130) displays a screen which was displayed in the rolled state on the part of the display which is newly exposed in a flat state.', 'The flexible display device (100) as claimed in claim 1,', 'The flexible display device (100) as claimed in claim 1, wherein in response to the display (110) partially being rolled in a direction of an inner surface so that the display surface forms a concave shape, the controller (130) constructs and displays the screen so as to correspond to a size and a shape of a remaining area excluding an area which is bent by rolling.', 'The flexible display device (100) as claimed in claim 1, wherein in response to the display (110) partially being rolled in a direction of an outer surface so that the display surface forms a convex shape, the controller (130) constructs and displays the screen so as to correspond to a size and a shape of a remaining area excluding an area which is in contact with the outer surface out of the inner surface of the display.', 'The flexible display device (100) as claimed in claim 1, wherein in response to the display being rolled (110), the controller (130) determines a size and a location of the exposed area based on a sensing result of the first sensor.', 'The flexible display device (100) as claimed in claim 1, wherein the second sensor comprises a pressure sensor configured to sense pressure which is applied to the display, and', 'A method of controlling a flexible display device (100) with a display (110), the method comprising:', 'The method as claimed in claim 10, wherein the reconstructing and displaying (S1630) comprises changing the screen so that an object displayed in the user grip area in the screen is moved to another area.', 'The method as claimed in claim 11, wherein the reconstructing and displaying (S1630) comprises expressing an animation effect of pushing the object by the user grip manipulation and gradually moving the object to the other area.']
# ['A hand-held device for treating hard skin comprising a barrel (1) for holding the device in use, a fluid reservoir (7) within the barrel (1), a dispensing device mounted at a first end of the barrel (1) for delivery of fluid from the reservoir (7) for application to the skin to be treated,', 'A hand-held device according to claim 1, wherein the cutting head (2) comprises a base (8) and at least two cutting elements (10) projecting from the base (8) and spaced apart from each other.', 'A hand-held device according to claim 2, wherein the cutting elements (10) have extremities lying in a skin contact plane (20) and each cutting edge lies in a plane inclined to the skin contact plane (20).', 'A hand-held device according to claim 3, wherein the inclined plane is at an angle in the range of from 5', 'A hand-held device according to any one of the claims 2 to 4, wherein the cutting elements (10) are tubular.', 'A hand-held device according to claim 5, wherein the cutting elements (10) are right circular cylindrical tubes, and the cutting edge of each cutting elements (10) lies in a plane perpendicular to the axis of the cutting element (10).', 'A hand-held device according to any one of claims 2 to 6, wherein the cutting elements (10) project from the base (8) along parallel axes.', 'A hand-held device according to any one of the preceding claims, wherein there are three or more cutting elements (10) positioned in a staggered array.', 'A hand-held device according to claim 8, wherein the cutting elements (10) are arranged in at least two rows extending transversely to a movement direction, the cutting element(s) (10) in one row being staggered with respect to the cutting elements (10) of another row.', 'A hand-held device according to any one of claims 2 to 9, wherein the base (8) comprises a plate to which the cutting elements (10) are fixed.', 'A hand-held device according to claim 10, wherein the plate has sockets (12) into which the respective cutting elements (10) are inserted.', 'A hand-held device according to claim 11, wherein the sockets (12) have inner ends that are open to a cavity (6) formed in the cutting head (2).', 'A hand-held device according to claim 12, wherein the cavity (6) is open to the exterior.', 'A hand-held device according to any one of the preceding claims, wherein the barrel (1) includes an inner barrel (5a) enclosing the reservoir and an outer barrel (5b) surrounding the inner barrel (5a).', 'A hand-held device according to claim 14, wherein the cutting head (2) has mounting parts respectively engaged with the inner and outer barrels (5a,5b)', 'A hand-held device according to claim 14 or 15, wherein the dispensing device is fitted into the inner barrel (5a).', 'A hand-held device according to any one of the preceding claims wherein the dispensing device comprises an applicator (27) for applying the fluid to the skin.', 'A hand-held device according to claim 17, wherein the applicator (27) is a roller ball applicator.', 'A hand-held device according to any one of the preceding claims wherein the reservoir (7) contains a fluid for softening hard skin.', 'A hand-held device according to any of the preceding claims wherein the reservoir (7) contains a hydrating gel.']
# ['Unavailable']
# ['Unavailable']
# ['A control system for a windpark power plant including plurality of wind turbines (12), said system comprising a central processing and control unit (16) operatively coupled to said wind turbines (12) to receive data from and transmit at least one of data and control signals (C1, C2, ..., Cn) to each said wind turbine (12), said central processing and control unit processing data received from at least one upstream turbine to predict a load impact on turbines downstream thereof, and selectively generating and transmitting control signals to at least one of {1} reduce power of at least one downstream wind turbine to minimize load impact and/or {2} reduce a speed of at least one said upstream turbine to reduce fatigue load and increase power capture in at least one downstream turbine.', 'A control system as in claim 1, wherein said control signals to reduce power comprise control signals to change rotor speed and/or blade pitch angle of the at least one downstream wind turbine (12).', 'A control system as in claim 1 or claim 2, wherein said control signals reduce the speed of the upstream turbine, but maintain the rotor speed of the upstream turbine above that of the at least one downstream turbine.', 'A control system of any preceding claim, wherein each said wind turbine (12) includes a local controller (14) for receiving data from the respective turbine.', 'A control system as in claim 4, wherein each said local controller (14) is operatively coupled to said central processing and control unit (16) for transmitting data to and receiving said data and/or control signals (C1, C2, ..., Cn)therefrom.', 'A method of controlling a windpark power plant that includes a plurality of wind turbines (12) and a central processing and control unit (16) operatively coupled to said wind turbines (12) to receive data from and selectively transmit at least one of data and control signals (C1, C2, ..., Cn) to each said wind turbine (12), said method comprising:', 'A method as in claim 6, wherein said control signals to reduce power comprise control signals to change rotor speed and/or blade pitch angle of the at least one downstream wind turbine (12).', 'A method as in claim 6 or claim 7, wherein said data received from said at least one turbine correspond to locally detected values of at least one of rotor and generator speeds, electrical power, generator torque, blade or pitch angle and pitch rate, wind velocity, and wind direction.', 'A method of any one of claims 6 to 8, wherein said transmitting comprises transmitting a measurement of the load and a measurement of the output power from each turbine (12) in the windpark to the central processing and control unit; and further comprising:', 'A method as in claim 9, wherein said transmitting further comprises transmitting wind speed and direction data and wherein said central processing and control unit (16) calculates optimal power production of the turbines (12) based on said data and based on wake interaction data with the aim of reducing fatigue loads.']
# ['Unavailable']
# ['Unavailable']
# ['Method for the efficient charging of vehicle batteries (12-i) of electric vehicles (11-i) by charging stations (2-i) of a group charging station (1),', 'Method according to claim 1,', 'Method according to claim 1 or 2,', 'Method according to claim 3,', 'Method according to claim 1 to 4,', 'Group charging station (1) for efficient charging of vehicle batteries (12-i) of electric vehicles (11-i) by respective charging stations (2-i) of the group charging station,', 'Group charging station according to claim 6,', 'Group charging station according to claim 6 or 7,', 'Group charging station according to claim 8,', 'Group charging station according to claim 9,', 'Group charging station according to claim 6 to 10,', 'Group charging station according to claim 6 to 11,', 'Group charging station according to claim 6 to 11,']
# ['Unavailable']
# ['Unavailable']
# ['A wind turbine system (10) comprising:', 'The system of claim 1 wherein the controller (32) is further configured to provide a wind blade pitch control signal or a turbine speed control signal (56) in response to the frequency disturbances or the power swings of the utility system (40) relative to the internal reference frame (62).', 'The system of claim 1 or claim 2 wherein the internal reference frame (62) is configured to output a variable frequency that may differ from the utility system (40) during transient conditions, and further comprising a difference element (68) configured to generate a relative frequency (66) comprising a difference between a measured utility system frequency (70) and an internal reference frame frequency (64).', 'The system of any preceding claim wherein the controller (32) is further configured for providing a supplemental input signal (50) to the converter (34), wherein the supplemental input signal (50) comprises a torque or power signal and is a function of at least one of a relative angle, a relative frequency, or time.', 'The system of claim 4 wherein the relative angle (74) is calculated from the integral of the relative frequency (66) multiplied by a constant to convert per unit frequency to radians.', 'The system of any preceding claim further comprising a limit function (90) configured for limiting a relative angle, a relative frequency of power flow modulation, a supplemental power or torque signal, or combinations thereof.', 'The system of claim 6 wherein the limit function (90) comprises limits that are operable as a function of at least one of a physical limitation on the wind turbine system, a power limit, a torque limit, a current limit, an energy limit, or a wind turbine generator rotor speed limit.', 'The system of any preceding claim wherein the wind turbine generator (18) is at least one of doubly fed asynchronous generator or a generator for use with a full converter.', 'The system of claim 8 further comprising an energy storage element, an energy consumer element or combinations thereof (60), wherein the energy storage element, the energy consumer element or the combinations thereof are coupled to the converter (34).', 'A wind farm management system (200), the system comprising']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Rectangular baler comprising:', 'Rectangular baler according to claim 1, wherein the at least one friction block (207, 307, 307\', 307") is fixed on an inner side of a top wall (202) of the bale chamber.', 'Rectangular baler according to claim 2, wherein the top wall (202) comprises a first wall part (202a) adjoining the plunger (203) and a second wall part (202b) adjoining the discharge opening, wherein said second wall part (202b) is inclined with respect to the first wall part (202a), and the at least one friction block (207, 307, 307\', 307") is fixed on said first wall part (202a).', 'Rectangular baler according to any of the previous claims, wherein a top wall (202) of the bale chamber comprises a plurality of slats (230) extending in the discharge direction (F) and spaced at a distance from each other, wherein the or each friction block (207, 307, 307\', 307") is fixed on a slat of the plurality of slats such that the inclined surface adjoins a surface delimiting the bale chamber.', 'Rectangular baler according to any of the previous claims, wherein the or each friction block (207, 307, 307\', 307") is fixed on the wall at a distance (D) from the plunger, when in an extended position, which is more than 10 cm, preferably more than 20 cm.', 'Rectangular baler according to any of the previous claims, wherein the or each friction block (207, 307, 307\', 307"), seen in a plane of the wall, perpendicular to the discharge direction (F), has a maximum width (W) which is larger than 2 cm, preferably larger than 3 cm.', 'Rectangular baler according to any of the previous claims, wherein the or each friction block (207, 307, 307\', 307"), seen in the discharge direction (F), has a maximum length (L1 + L2) which is larger than 5 cm, preferably larger than 10 cm.', 'Rectangular baler according to any of the previous claims, wherein said friction block (207, 307) comprises a beam shaped part (212, 312) connected to the wedge shaped part (211, 311) such that, seen in the discharge direction (F), the inclined surface (213, 313) goes over in a top surface (214, 314) of the beam shaped part (212, 312).', 'Rectangular baler according to claim 8, wherein the wedge shaped part (211, 311, 311\', 311") has a length, seen in the discharge direction (F), which is larger than 3 cm, preferably larger than 5 cm, most preferably larger than 8 cm; and/or wherein the beam shaped part (212, 312) has a length (L2), seen in the discharge direction (F), which is larger than 2 cm, preferably larger than 3 cm.', 'Rectangular baler according to any of the previous claims, wherein a row of friction blocks (207, 307, 307\', 307") is fixed to the wall spaced at a distance from each other, at substantially the same distance from the plunger (203).', 'Rectangular baler according to any of the previous claims, wherein the bale chamber has a top wall and sidewalls, wherein the top wall (202) is hinged around a pivot axis (220) extending between two sides of the bale chamber at the plunger end of the bale chamber, and wherein the baler comprises an actuator to exert a pressure on the top wall and/or on the side walls.', 'Rectangular baler according to any of the previous claims, wherein a width (W) of the or each friction block (207, 307, 307\', 307") is at least 10 times smaller than a width of the bale chamber seen in a direction perpendicular to the discharge direction (F).']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A process of recovery of base metals from an oxide ore including a first metal selected from the group consisting of iron, magnesium and aluminum, and a second metal selected from the group consisting of nickel, cobalt and copper, the process comprising:', 'The process according to claim 1, wherein, before contacting the oxide ore with at least one of ferric or ferrous chloride, reducing ore particle size from about 2 mm to about 0.050 mm or from about 2 mm to less than 0.5 mm.', 'The process according to claim 1, wherein the ferric chloride is added in a ratio of between 0.05 and 1.5 times an oxide ore mass, or between 0.1 to 0.5 times the oxide ore mass.', 'The process according to claim 1, wherein the ferrous chloride is added in a ratio of between 0.05 and 1.5 times an oxide ore mass, or between 0.1 to 0.5 times the oxide ore mass.', 'The process according to claim 4, wherein an oxidizing agent is added to the oxide ore in a ratio between 0.0001 and 10 times the ore mass to react with the ferrous chloride.', 'The process according to claim 5, wherein the oxidizing agent is selected from the group consisting of oxygen, potassium permanganate, ozone and hydrogen peroxide.', 'The process according to claim 1, wherein the heating is performed at a temperature ranging from about 60°C to about 600°C, or from about 100 °C to about 300 °C.', 'The process according to claim 1, wherein heating is performed for a period of time ranging from about 0.5 hours to about 12 hours.', 'The process according to claim 1, further comprising adding water during the heating of the mixture.', 'The process according to claim 9, wherein the adding of the water further comprises a wet air injection.', 'The process according to claim 1, wherein the oxide ore is stacked in a heap and leached with acidified water comprising hydrochloric acid up to about 100g/L and at a pH of between about 1 and about 3, at least one of prior to or during selective dissolution of the second metal chlorides.', 'The process according to claim 1, further comprising a solid-liquid separation step after selectively dissolving the second metal chlorides.', 'The process according to claim 12, wherein tailings from the solid-liquid separation step are contacted with a high intensity magnetic field to separate the hematite.', 'The process according to claim 1, further comprising:', 'The process according to claim 14, wherein the reducing agent comprises a metallic iron.']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A load management controller (3, 53, 73) for a household electrical installation (1), the household electrical installation (1) comprising a main panel (5) receiving electricity from a pair of electricity supplies (7, 9) and distributing the electricity to a plurality of electrical sub-circuits (19, 21, 23, 25 and 27), one of which being an energy storage sub-circuit (19), the pair of electricity supplies comprising a grid supply (7) and a micro-generator supply (9), the household electrical installation further comprising:', 'A load management controller (3, 53, 73) as claimed in claim 1 in which the energy storage sub-circuit (19) comprises an energy storage device.', 'A load management controller (3, 53, 73) as claimed in claim 2 in which the energy storage device comprises one or more of an electrical immersion (29), a storage heating unit, a static rechargeable battery bank (55), a rechargeable battery pack of a motorised vehicle and an electrical under floor heating unit (31).', 'A load management controller (3, 53, 73) as claimed in any preceding claim in which each of the electrical sub-circuits (19, 21, 23, 25 and 27) has an electricity usage profile containing rules determining the supply of electricity to the electricity sub-circuit associated therewith, the load management controller (3) comprising means (57) to access the electricity usage profiles and means (59) to control supply of electricity to the electrical sub-circuits (19, 21, 23, 25 and 27) having an electricity usage profile in accordance with the rules of the electricity usage profile for that electrical sub-circuit.', 'A load management controller (3, 53, 73) as claimed in claim 4 in which the means to control supply of electricity to the electrical sub-circuits further comprises a thyristor (33, 35), responsive to the load management controller (3), intermediate the electricity power supply (7, 9) and the electrical sub-circuit (19, 21) having an electricity usage profile.', 'A load management controller (3, 53, 73) as claimed in claim 4 in which the means to control supply of electricity to the electrical sub-circuits further comprises a speed controller (39), responsive to the load management controller (73), intermediate the electricity power supply (7, 9) and the electrical sub-circuit (25) having an electricity usage profile.', 'A load management controller (3, 53, 73) as claimed in any preceding claim in which the load management controller has means to export electricity from a rechargeable battery bank onto an electricity supply grid (7).', 'A load management controller (3, 53, 73) as claimed in claim 7 in which the load management controller exports the electricity to the electricity supply grid in response to a request for electricity received from a remote electricity power supply operator.', 'A load management controller (3, 53, 73) for a household electrical installation (1) as claimed in any preceding claim in which one of the electricity sub-circuits comprises a rechargeable static battery bank (55) operable as an alternative power supply to the remaining electrical sub-circuits (19, 21, 23, 25 and 27) in the household electrical installation.', 'A load management controller (3, 53, 73) as claimed in claim 9 comprising means to select one of the rechargeable static battery bank (55) and a grid power supply (7) to provide power to one or more of the remaining electrical sub-circuits.', 'A load management controller (3, 53, 73) for a household electrical installation (1) as claimed in any preceding claim in which one of the electricity sub-circuits comprises a rechargeable battery bank (55) in an electric vehicle operable as an alternative power supply to the remaining electrical sub-circuits (19, 21, 23, 25 and 27) in the household electrical installation.', 'A load management controller (3, 53, 73) as claimed in any preceding claim in which the micro-generator supply further comprises a dedicated inverter/controller circuit.', 'A hous ...
# ['A wind turbine (10), comprising:', 'The wind turbine (10) of claim 1, wherein the pitch control system (42) comprises means for controlling sampling the upwind transient wind dynamics at a desired distance from the wind turbine generator (10) in a direction of the wind.', 'The wind turbine (10) of any preceding claim, wherein the pitch control system (42) further comprises means configured for utilizing the feed forward signal to determine a preemptive blade pitch command signal to control pitch of no more than one individual wind turbine blade (14,16,18) in advance of a change in transient wind dynamics at the wind turbine blade (14,16,18).', 'A method for controlling rotor (12) imbalance of the wind turbine generator (10) of any preceding claim in response to an anticipated change in wind dynamics, comprising:']
# ['Unavailable']
# ['Unavailable']
# ['A protective circuit (10) for a multi-level converter (12) including a DC link (16) capacitor bank (14), the protective circuit comprising:', 'The protective circuit (10) of claim 1 wherein the controller is configured for providing pulse width modulation control during normal operating conditions and for actuating the switches during transient conditions.', 'The protective circuit (10) any preceding claim wherein the converter comprises a three level converter.', 'The protective circuit (10) of any preceding claim, further comprising two diodes (28, 30), wherein the energy absorbing element comprises at least two energy absorbing elements, wherein the capacitor bank comprises at least two capacitors (32, 34) and wherein', 'The protective circuit (10) of any preceding claim wherein the energy absorbing element comprises at least two energy absorbing elements with at least one of the energy absorbing elements having a smaller rating than another of the energy absorbing elements and being coupled to a neutral point of the capacitor bank.', 'A power generation system comprising:', 'The power generation system of claim 6 further comprising a wind turbine generator (56) coupled to the multi-level converter.', 'The power generation system of claim 6 or claim 7 further comprising a motor (59) coupled to the multi-level converter, wherein the a motor is incorporated in an assembly for obtaining oil, gas, or combinations thereof.', 'A method for providing energy dissipation control and voltage balance control for a multi-level converter (12) including a DC link (16) capacitor bank (14) comprising at least one mid-point (136,236) at a potential between a positive voltage rail (46) and a negative voltage rail (48), an energy absorbing element (18, 20), and protective switches (22, 24), wherein at least two of the protective switches each couple the energy absorbing element to the capacitor bank (14), the method ', 'The method of claim 9 wherein providing control signals comprises providing pulse width modulation control signals to phases leg switches of the multi-level converter during normal operating conditions and providing control signals for actuating the protective switches during transient conditions.']
# ...
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A method for installing vortex generator accessories (102) to a suction (24) or pressure side (22) of a wind turbine rotor blade (16), wherein the vortex generator accessories (102) each have a base portion (104) and at least one protrusion member (108) extending upwardly from the base portion (104), the method comprising:', 'The method claim 1, wherein the vortex generator accessories (102) are attached to the suction (24) or pressure side (22) with use of an attachment layer (110) connecting the base portion (104) to the suction (24) or pressure side (22), the attachment layer (110) having a lower shear modulus than the base portion (104) to allow for shear slippage between the base portion (104) and the underlying suction or pressure side (24, 22).', 'The method of claim 1 or 2, wherein the attachment layer (110) comprises a foam-based strip member with adhesive on opposite interface sides thereof.', 'The method of claim 3, wherein the attachment layer (110) comprises a Very High Bond (VHB) or SAFT (Solar Acrylic Foam Tape) foam-based strip material.', 'The method of any preceding claim, wherein the template (122) is defined on a sheet member that contours to the wind turbine rotor blade (16).', 'The method of any preceding claim, wherein the vortex generator accessories comprise a plurality of the protrusion members extending from the base portion.', 'The method of claim 6, wherein the protrusion members are arranged in a V-shaped formation on the base portion.', 'The method of any preceding claim, wherein pairs of the vortex generator accessories are mounted span-wise along the blade so as to define V-shaped formations along the suction or pressure side.']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A vortex generator for a wind turbine blade comprising:', 'The vortex generator of claim 1, wherein at least the portion of the suction side of the fluid foil comprises a conic surface with a vertex proximate a front end of the suction side of the fluid foil.', 'The vortex generator of claim 1, or claim 2, wherein the vortex nest comprises a distal portion of the fluid foil curling over the suction side thereof and forming a suction side span-wise concavity from the progressive fillet to the distal portion.', 'The vortex generator of claim 3, wherein the concavity is continuous from the fillet to the distal portion.', 'The vortex generator of any of claims 1 to 4, further comprising a second fluid foil comprising a mirror image of the fluid foil of claim 1 across a mirror plane between the suction sides of the two fluid foils, wherein the two fluid foils are disconnected from each other and diverge from each other from front to back, and wherein the progressive fillets on the suction sides of the two fluid foils converge toward each other from front to back along the larger aerodynamic surface.', 'The vortex generator of any of claims 1 to 5, further comprising a fillet between a trailing edge of the fluid foil and the larger aerodynamic surface, wherein the trailing edge fillet comprises a ridge spanning between the trailing edge and the larger aerodynamic surface.', 'The vortex generator of claim 6, wherein:', 'The vortex generator of claim 7, wherein the continuous contour forms the vortex nest with an axis of concavity that diverges from the angle of incidence toward the free stream flow and curves toward a direction of the free stream flow by at least 5 degrees of curvature.', 'The vortex generator of any preceding claim, wherein the fluid foil comprises a relatively thick root portion attached to the larger aerodynamic surface and a relatively thin leading edge extending outward and angled back from a front end of the root portion, wherein the leading edge of the fluid foil has only a single apex as seen in transverse sections taken along at least most of the leading edge.', 'The vortex generator of claim 9, wherein the leading edge has a net curvature from the pressure side toward the suction side of the fluid foil as viewed in the transverse sections.', 'The vortex generator of any preceding claim, wherein the vortex nest comprises a distal portion of the fluid foil curling over the suction side thereof.', 'The vortex generator of any preceding claim, wherein the fluid foil further comprises a serrated trailing edge.', 'The vortex generator of claim 1, wherein the vortex nest is formed by at least a portion of the suction side of the fluid foil being concave span-wise, and comprising an axis of concavity that curves away from an angle of incidence of the fluid foil toward a free stream flow at a back end of the fluid foil.', 'The vortex generator of claim 1, wherein each structure further comprises:', 'A vortex generator for a wind turbine blade, the vortex generator comprising:']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A control system for a power system comprising:', 'The control system for a power system according to claim 1,', 'The control system for a power system according to claim 1 or claim 2,', 'The control system for a power system according to claim 1 or claim 2,', 'The control system for a power system according to claim 1,']
# ['Unavailable']
# ['Unavailable']
# ['A rotor blade (22) for a wind turbine (10), said rotor blade (22) comprising:', 'The rotor blade (22) as in claim 1, wherein said alignment structure (38) is fixed substantially adjacent to said blade root (25).', 'The rotor blade (22) as in any preceding claim, wherein said first base (32) abuts against said chord-wise extending face (44).', 'The rotor blade (22) as in any preceding claim, wherein said tail end (46) and said connector end (48) comprise a mating first dovetail configuration (52).', 'The rotor blade (22) as in any preceding claim, further comprising a plurality of second bases (34), each second base (34) having at least one connector end (48) and a plurality of airflow modifying elements (40), wherein each connector end (48) is coupled with a corresponding connector end of a different second base (34).', 'The rotor blade (22) as in claim 5, wherein each connector end (48) and each corresponding connector end (48) comprise a mating second dovetail configuration (54).', 'The rotor blade (22) as in any preceding claim, wherein each dovetail configuration (52, 54) is unique such that said plurality of second bases (32) are coupled together in a predetermined order.', 'The rotor blade (22) as in any preceding claim, wherein said alignment structure (38) is one of a root flange (28), a pitch bearing (24), or a root band.', 'The rotor blade (22) as in any preceding claim, wherein said first base (32) and said plurality of second bases (34) are shaped to substantially correspond to at least one of said suction side surface or pressure side surface, and wherein said first base and said plurality of second bases (34) are adhered to at least one of the suction side surface or the pressure side surface with an adhesive (58).', 'A method for aligning airflow modifying elements (40) on a rotor blade (22), said method comprising:', 'The method as in claim 10, wherein the interconnecting profile (42) and the complimentary interconnecting profile comprise a mating first dovetail configuration (52).', 'The method as in claim 10 or claim 11, further comprising abutting the root end (39) of the first base (32) against the chord-wise extending face of the alignment structure (38).', 'The method as in any of claims 10 to 12, further comprising connecting a plurality of second bases (34) to the first base (32).', 'The method as in any of claims 10 to 13, wherein the first base (32) and the plurality of second bases (34) are connected so as to align substantially parallel to a span-wise axis.', 'The method as in any of claims 10 to 14, wherein the first base (32) and the plurality of second bases (34) are connected so as to maintain a chord-wise distance from a trailing edge of the rotor blade (22).']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A method (1000) for controlling a wind farm (300, 400), the method comprising:', 'The method (1000) of claim 1, wherein dividing the wind farm comprises at least one of:', 'The method (1000) of claim 1 or claim 2, wherein selecting the wind turbines (10) is performed in accordance with a maintenance state of the wind turbines (10), a load state of the wind turbines, a wind condition of the wind turbines, an error state of the wind turbines and/or a curtailment operation time of the wind turbines.', 'The method (1000) of any preceding claim, wherein determining the actual power production of the first group of wind turbines comprises at least one of:', 'The method (1000) of any preceding claim, wherein estimating the possible maximum power production of the second group of wind turbines (10) comprises at least one of:', 'The method (1000) of any preceding claim, wherein estimating the possible maximum power output of the wind farm comprises at least one of:', 'The method (1000) of any preceding claim, wherein estimating the power reserve comprises at least one of:', 'The method (1000) of any preceding claim, wherein determining the power setpoint comprises at least one of:', 'A wind farm (300, 400), comprising:']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['A method for controlling wind alignment correction of a wind turbine, comprising:', 'The method according to claim 1, wherein the determining local maximum values of the generation power values extracted for the respective wind speed sections comprises:', 'The method according to claim 2, wherein the calculating the wind alignment correction deviation of the wind turbine based on the wind alignment angle measurement values extracted for the respective wind speed sections and corresponding to the determined local maximum values of the generation power values comprises:', 'The method according to claim 3, wherein the correcting the wind alignment angle measurement values to be acquired subsequently by using the wind alignment correction deviation comprises:', 'The method according to any one of claims 1 to 4, further comprising:', 'A device for controlling wind alignment correction of a wind turbine, comprising:', 'The device according to claim 6, wherein the determining module is configured to:', 'The device according to claim 7, wherein the calculating module is configured to:', 'The device according to claim 8, wherein the correcting module is configured to:', 'The device according to any one of claims 6 to 9, further comprising:', 'A system for controlling wind alignment correction of wind turbines, comprising a cluster controller and stand-alone controllers provided on the wind turbines, wherein']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['An optical scanning device (11), comprising:', 'An optical scanning device according to claim 1, wherein:', 'An optical scanning device according to claims 1 or 2, further comprising a pressing member (23) capable of changing a posture between a first posture in which the pressing member is mounted at a predetermined position of the housing and a second posture in which the pressing member is separated from the predetermined position, wherein:', 'An optical scanning device according to claim 3, wherein:', 'An optical scanning device according to claim 4, further comprising:', 'An image forming apparatus, comprising:']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']
# ['Unavailable']

# %%
# iterating through all pairs of patents to get their pairwise similarity
for patent in model.patent_list:
    index = model.dict_patents_indexes[patent]
    print(model.corpus_stemmed[index])
# Out:
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
ein the measur devic compris sensor for track deliveri monitor a fleet of vehicl or sensor for measur affluenc traffic of certain locat method accord to ani one of previous claim wherein the communic devic associ to the sourc is a portabl comput devic with communic capabl as a mobil phone or a tablet method accord to ani one of previous claim wherein the compar of step e further compris logic to compar non-numer metadata system for anonym associ measur devic measur to a sourc id the system be server for anonym associ measur devic measur to a sourc id the server be comput program product compris comput program code adapt to perform the method accord to ani of the claim 1-12 when said program code is execut on a comput a digit signal processor a field-programm gate array an application-specif integr circuit a micro-processor a micro-control or ani other form of programm hardwar
# a computer-impl method for generat a 3-dimension represent of a tunnel the method compris the step of the method for generat a 3-dimension represent of a tunnel accord to claim 1 wherein each tunnel wall further contain at it upper end a curv surfac the curv surfac of the left and right tunnel wall build a tunnel ceil the method for generat a 3-dimension represent of a tunnel accord to claim 1 or 2 wherein the predefin pattern 13 contain an entranc and or exit portal of the tunnel the 3-dimension represent of the tunnel be generat use the entranc and or exit portal the method for generat a 3-dimension represent of a tunnel accord to claim 1 wherein the 3-dimension tunnel bodi 20 further includ a tunnel ceil the method for generat a 3-dimension represent of a tunnel accord to claim 1 or 4 wherein the posit of the tunnel bodi 20 below the surfac of the earth is determin by elev data of a tunnel entranc and of a tunnel exit the method for generat a 3-dimension represent of a tunnel accord to ani one of the preced claim further compris the step of identifi the right and left tunnel wall for each drive direct in the tunnel and store the identifi left and right tunnel wall for each drive direct in the 3-dimension represent of the tunnel a system configur to generat a 3 dimension represent of a tunnel the system compris the system configur to generat a 3-dimension represent of a tunnel accord to claim 7 wherein the data process unit 14 is configur to emb the tunnel bodi below the surfac of the earth in such a way that the posit of the tunnel bodi 20 below the surfac of the earth is determin by elev data of a tunnel entranc and of a tunnel exit the system configur to generat a 3-dimension represent of a tunnel accord to claim 7 or 8 wherein the data process unit 14 is configur to identifi the right and left tunnel wall for each drive direct in the tunnel and configur to store the identifi left and right tunnel wall for each drive direct in the 3-dimension represent of the tunnel
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# a flexibl display devic 100 compris the flexibl display devic 100 as claim in claim 1 wherein the control 130 chang the screen so that an object display in the user grip area in the screen is move to anoth area the flexibl display devic 100 as claim in claim 2 wherein the control 130 express an anim effect of push the object by the user grip manipul and gradual move the object to the other area the flexibl display devic 100 as claim in claim 1 wherein in respons to the roll state be releas so that at least part of the display is in a flat state the control 130 display a screen which was display in the roll state on the part of the display which is newli expos in a flat state the flexibl display devic 100 as claim in claim 1 the flexibl display devic 100 as claim in claim 1 wherein in respons to the display 110 partial be roll in a direct of an inner surfac so that the display surfac form a concav shape the control 130 construct and display the screen so as to correspond to a size and a shape of a remain area exclud an area which is bent by roll the flexibl display devic 100 as claim in claim 1 wherein in respons to the display 110 partial be roll in a direct of an outer surfac so that the display surfac form a convex shape the control 130 construct and display the screen so as to correspond to a size and a shape of a remain area exclud an area which is in contact with the outer surfac out of the inner surfac of the display the flexibl display devic 100 as claim in claim 1 wherein in respons to the display be roll 110 the control 130 determin a size and a locat of the expos area base on a sens result of the first sensor the flexibl display devic 100 as claim in claim 1 wherein the second sensor compris a pressur sensor configur to sens pressur which is appli to the display and a method of control a flexibl display devic 100 with a display 110 the method compris the method as claim in claim 10 wherein the reconstruct and display s1630 compris chang the screen so that an object display in the user grip area in the screen is move to anoth area the method as claim in claim 11 wherein the reconstruct and display s1630 compris express an anim effect of push the object by the user grip manipul and gradual move the object to the other area
 a local control 14 for receiv data from the respect turbin a control system as in claim 4 wherein each said local control 14 is oper coupl to said central process and control unit 16 for transmit data to and receiv said data and or control signal c1 c2 cn therefrom a method of control a windpark power plant that includ a plural of wind turbin 12 and a central process and control unit 16 oper coupl to said wind turbin 12 to receiv data from and select transmit at least one of data and control signal c1 c2 cn to each said wind turbin 12 said method compris a method as in claim 6 wherein said control signal to reduc power compris control signal to chang rotor speed and or blade pitch angl of the at least one downstream wind turbin 12 a method as in claim 6 or claim 7 wherein said data receiv from said at least one turbin correspond to local detect valu of at least one of rotor and generat speed electr power generat torqu blade or pitch angl and pitch rate wind veloc and wind direct a method of ani one of claim 6 to 8 wherein said transmit compris transmit a measur of the load and a measur of the output power from each turbin 12 in the windpark to the central process and control unit and further compris a method as in claim 9 wherein said transmit further compris transmit wind speed and direct data and wherein said central process and control unit 16 calcul optim power product of the turbin 12 base on said data and base on wake interact data with the aim of reduc fatigu load
# unavail
# unavail
# method for the effici charg of vehicl batteri 12-i of electr vehicl 11-i by charg station 2-i of a group charg station 1 method accord to claim 1 method accord to claim 1 or 2 method accord to claim 3 method accord to claim 1 to 4 group charg station 1 for effici charg of vehicl batteri 12-i of electr vehicl 11-i by respect charg station 2-i of the group charg station group charg station accord to claim 6 group charg station accord to claim 6 or 7 group charg station accord to claim 8 group charg station accord to claim 9 group charg station accord to claim 6 to 10 group charg station accord to claim 6 to 11 group charg station accord to claim 6 to 11
# unavail
# unavail
# a wind turbin system 10 compris the system of claim 1 wherein the control 32 is further configur to provid a wind blade pitch control signal or a turbin speed control signal 56 in respons to the frequenc disturb or the power swing of the util system 40 relat to the intern refer frame 62 the system of claim 1 or claim 2 wherein the intern refer frame 62 is configur to output a variabl frequenc that may differ from the util system 40 dure transient condit and further compris a differ element 68 configur to generat a relat frequenc 66 compris a differ between a measur util system frequenc 70 and an intern refer frame frequenc 64 the system of ani preced claim wherein the control 32 is further configur for provid a supplement input signal 50 to the convert 34 wherein the supplement input signal 50 compris a torqu or power signal and is a function of at least one of a relat angl a relat frequenc or time the system of claim 4 wherein the relat angl 74 is calcul from the integr of the relat frequenc 66 multipli by a constant to convert per unit frequenc to radian the system of ani preced claim further compris a limit function 90 configur for limit a relat angl a relat frequenc of power flow modul a supplement power or torqu signal or combin thereof the system of claim 6 wherein the limit function 90 compris limit that are oper as a function of at least one of a physic limit on the wind turbin system a power limit a torqu limit a current limit an energi limit or a wind turbin generat rotor speed limit the system of ani preced claim wherein the wind turbin generat 18 is at least one of doubli fed asynchron generat or a generat for use with a full convert the system of claim 8 further compris an energi storag element an energi consum element or combin thereof 60 wherein the energi storag element the energi consum element or the combin thereof are coupl to the convert 34 a wind farm manag system 200 the system compris
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# a load manag control 3 53 73 for a household electr instal 1 the household electr instal 1 compris a main panel 5 receiv electr from a pair of electr suppli 7 9 and distribut the electr to a plural of electr sub-circuit 19 21 23 25 and 27 one of which be an energi storag sub-circuit 19 the pair of electr suppli compris a grid suppli 7 and a micro-gener suppli 9 the household electr instal further compris a load manag control 3 53 73 as claim in claim 1 in which the energi storag sub-circuit 19 compris an energi storag devic a load manag control 3 53 73 as claim in claim 2 in which the energi storag devic compris one or more of an electr immers 29 a storag heat unit a static recharg batteri bank 55 a recharg batteri pack of a motoris vehicl and an electr under floor heat unit 31 a load manag control 3 53 73 as claim in ani preced claim in which each of the electr sub-circuit 19 21 23 25 and 27 has an electr usag profil contain rule determin the suppli of electr to the electr sub-circuit associ therewith the load manag control 3 compris mean 57 to access the electr usag profil and mean 59 to control suppli of electr to the electr sub-circuit 19 21 23 25 and 27 have an electr usag profil in accord with the rule of the electr usag profil for that electr sub-circuit a load manag control 3 53 73 as claim in claim 4 in which the mean to control suppli of electr to the electr sub-circuit further compris a thyristor 33 35 respons to the load manag control 3 intermedi the electr power suppli 7 9 and the electr sub-circuit 19 21 have an electr usag profil a load manag control 3 53 73 as claim in claim 4 in which the mean to control suppli of electr to the electr sub-circuit further compris a speed control 39 respons to the load manag control 73 intermedi the electr power suppli 7 9 and the electr sub-circuit 25 have an electr usag profil a load manag control 3 53 73 as claim in ani preced claim in which the load manag control has mean to export electr from a recharg batteri bank onto an electr suppli grid 7 a load manag control 3 53 73 as claim in claim 7 in which the load manag control export the electr to the electr suppli grid in respons to a request for electr receiv from a remot electr power suppli oper a load manag control 3 53 73 for a household electr instal 1 as claim in ani preced claim in which one of the electr sub-circuit compris a recharg static batteri bank 55 oper as an altern power suppli to the remain electr sub-circuit 19 21 23 25 and 27 in the household electr instal a load manag control 3 53 73 as claim in claim 9 compris mean to select one of the recharg static batteri bank 55 and a grid power suppli 7 to provid power to one or more of the remain electr sub-circuit a load manag control 3 53 73 for a household electr instal 1 as claim in ani preced claim in which one of the electr sub-circuit compris a recharg batteri bank 55 in an electr vehicl oper as an altern power suppli to the remain electr sub-circuit 19 21 23 25 and 27 in the household electr instal a load manag control 3 53 73 as claim in ani preced claim in which the micro-gener suppli further compris a dedic invert control circuit a household electr instal 1 51 71 compris a main panel 5 receiv electr from a pair of electr suppli 7 9 and distribut the electr to a plural of electr sub-circuit 19 21 23 25 and 27 one of which be an energi storag sub-circuit 19 55 the pair of electr suppli compris a grid suppli 7 and a micro-gener suppli 9 the household electr instal further compris a load manag control 3 the household electr instal compris
# a wind turbin 10 compris the wind turbin 10 of claim 1 wherein the pitch control system 42 compris mean for control sampl the upwind transient wind dynam at a desir distanc from the wind turbin generat 10 in a direct of the wind the wind turbin 10 of ani preced claim wherein the pitch control system 42 further compris mean configur for util the feed forward signal to determin a preemptiv blade pitch command signal to control pitch of no more than one individu wind turbin blade 14 16 18 in advanc of a chang in transient wind dynam at the wind turbin blade 14 16 18 a method for control rotor 12 imbal of the wind turbin generat 10 of ani preced claim in respons to an anticip chang in wind dynam compris
# unavail
# unavail
# a protect circuit 10 for a multi-level convert 12 includ a dc link 16 capacitor bank 14 the protect circuit compris the protect circuit 10 of claim 1 wherein the control is configur for provid puls width modul control dure normal oper condit and for actuat the switch dure transient condit the protect circuit 10 ani preced claim wherein the convert compris a three level convert the protect circuit 10 of ani preced claim further compris two diod 28 30 wherein the energi absorb element compris at least two energi absorb element wherein the capacitor bank compris at least two capacitor 32 34 and wherein the protect circuit 10 of ani preced claim wherein the energi absorb element compris at least two energi absorb element with at least one of the energi absorb element have a smaller rate than anoth of the energi absorb element and be coupl to a neutral point of the capacitor bank a power generat system compris the power generat system of claim 6 further compris a wind turbin generat 56 coupl to the multi-level convert the power generat system of claim 6 or claim 7 further compris a motor 59 coupl to the multi-level convert wherein the a motor is incorpor in an assembl for obtain oil gas or combin thereof a method for provid energi dissip control and voltag balanc control for a multi-level convert 12 includ a dc link 16 capacitor bank 14 compris at least one mid-point 136 236 at a potenti between a posit voltag rail 46 and a negat voltag rail 48 an energi absorb element 18 20 and protect switch 22 24 wherein at least two of the protect switch each coupl the energi absorb element to the capacitor bank 14 the method the method of claim 9 wherein provid control signal compris provid puls width modul control signal to phase leg switch of the multi-level convert dure normal oper condit and provid control signal for actuat the protect switch dure transient condit
# a power control method for secondari batteri 3 constitut a power storag compens 5 in a grid connect system 8 suppli electr power to a power system 1 by combin a power generat 7 whose output power p the power control method for secondari batteri 3 accord to claim 1 wherein the secondari batteri 3 divid into the constant power control group and the demand respons group are interchang the power control method for secondari batteri 3 accord to claim 1 or 2 wherein the number of the secondari batteri 3 belong to the constant power control group and the demand respons group are chang the power control method for secondari batteri 3 accord to claim 1 wherein the delay respons group is further divid into plural group plural input-output power subject to a primari delay filter process with chang a time constant are distribut to each group to control input-output power of the secondari batteri 3 respect depend on the belong group the power control method for secondari batteri 3 accord to ani one of claim 1 to 4 wherein the secondari batteri 3 are sodium-sulfur batteri the power control method for secondari batteri 3 accord to ani one of claim 1 to 5
# unavail
# unavail
# unavail
# a wind turbin blade compris wind turbin blade accord to claim 1 wherein the first and second row of vortex generat are provid along the outer half part of the longitudin extend of the blade prefer along at least 30 of the outer half part of the longitudin extend of the blade prefer along at least 50 of the outer half part of the longitudin extend of the blade a wind turbin blade accord to claim 1 or 2 wherein the first row of vortex generat extend at a chord wise distanc from the lead edg in the rang from 10 to 40 of the chord length prefer at a chord wise distanc from the lead edg in the rang from 15 to 35 of the chord length a wind turbin blade accord to ani of the preced claim wherein the second row of vortex generat extend at a chord wise distanc from the lead edg in the rang from 30 to 70 of the chord length prefer at a chord wise distanc from the lead edg in the rang from 40 to 60 of the chord length a wind turbin blade accord to ani of the preced claim wherein the height of said vortex generat of the first row is within the rang of 0 15 and 0 35 of the chord length a wind turbin blade accord to ani of the preced claim wherein the height of said vortex generat of the second row is within the rang of
# a method 41 compris the method 41 of claim 1 wherein the predict futur speed of the wind turbin 10 compris at least one of a predict futur speed of a rotor of the wind turbin and a predict futur speed of a generat of the wind turbin the method 41 of ani preced claim wherein the method 41 of ani preced claim wherein control 49 the wind turbin 10 compris appli at least one of a mechan brake a hydraul park brake an electromechan brake a centrifug brake an eddie-curr brake a yaw brake and a magnet brake to control a rotor of the wind turbin the method 41 of ani preced claim wherein control 49 the wind turbin 10 compris vari an actual rate of chang of blade pitch angl with respect to a predefin rate of chang of blade pitch angl the method 41 of ani preced claim further compris the method 41 of claim 6 further compris the method 41 of ani preced claim further wherein a control system 28 for a wind turbin 10 the control system compris the control system 28 of claim 9 wherein the predict futur speed of the wind turbin 10 compris at least one of a predict futur speed of a rotor of the wind turbin and a predict futur speed of a generat of the wind turbin the control system 28 of claim 9 or claim 10 further compris the control system 28 of claim 11 wherein the databas 44 further store the predict futur speed of the wind turbin correspond to the at least one oper paramet valu and the at least one environment paramet valu the control system 28 of claim 11 or claim 12 wherein the databas 44 further store at least one valu associ with the threshold speed the control system 28 of ani of claim 9 to 13 wherein the processor 42 is program to generat control signal to actuat at least one of a mechan brake a hydraul park brake an electromechan brake a centrifug brake an eddie-curr brake and a magnet brake on a rotor of the wind turbin to control the wind turbin the control system 28 of ani of claim 9 to 14 wherein the processor 42 is program to generat control signal to vari an actual rate of chang of blade pitch angl with respect to a predefin rate of chang of blade pitch angl to control the wind turbin
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# an electromagnet brake system compris the electromagnet brake system of claim 1 wherein the induct unit compris the electromagnet brake system of claim 1 wherein the at least one status signal is repres of the rotat speed of the rotat shaft a voltag in the power grid a current at the generat a mechan power produc by the prime mover a rotor angl of the generat an electr power produc by the generat or combin thereof the electromagnet brake system of claim 3 wherein the control is configur to caus the control signal to appli the electromagnet brake forc when the mechan power produc by the prime mover is abov a first threshold power or the electr power produc by the generat is below a second threshold power the electromagnet brake system of claim 3 wherein the control is configur to caus the control signal to initi and regul the electromagnet brake forc when the current at the generat is abov a threshold current the electromagnet brake system of claim 3 wherein the control is configur to caus the control signal to stop or regul the power produc by the prime mover base on the receiv status signal a method compris the method of claim 7 wherein appli the electromagnet brake forc on the rotat shaft compris the method of claim 8 wherein creat the first magnet field around the electr conduct disc compris send at least one of an altern current and a direct current to a plural of inductor wherein the at least one of the altern current and the direct current is correspond to the control signal the method of claim 9 further compris the method of claim 9 further compris the method of claim 9 further compris the method of claim 7 further compris a power generat system compris the power generat system of claim 14 wherein the electromagnet brake unit compris
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# a method for instal vortex generat accessori 102 to a suction 24 or pressur side 22 of a wind turbin rotor blade 16 wherein the vortex generat accessori 102 each have a base portion 104 and at least one protrus member 108 extend upward from the base portion 104 the method compris the method claim 1 wherein the vortex generat accessori 102 are attach to the suction 24 or pressur side 22 with use of an attach layer 110 connect the base portion 104 to the suction 24 or pressur side 22 the attach layer 110 have a lower shear modulus than the base portion 104 to allow for shear slippag between the base portion 104 and the under suction or pressur side 24 22 the method of claim 1 or 2 wherein the attach layer 110 compris a foam-bas strip member with adhes on opposit interfac side thereof the method of claim 3 wherein the attach layer 110 compris a veri high bond vhb or saft solar acryl foam tape foam-bas strip materi the method of ani preced claim wherein the templat 122 is defin on a sheet member that contour to the wind turbin rotor blade 16 the method of ani preced claim wherein the vortex generat accessori compris a plural of the protrus member extend from the base portion the method of claim 6 wherein the protrus member are arrang in a v-shape format on the base portion the method of ani preced claim wherein pair of the vortex generat accessori are mount span-wis along the blade so as to defin v-shape format along the suction or pressur side
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
#
the suction side surfac or the pressur side surfac with an adhes 58 a method for align airflow modifi element 40 on a rotor blade 22 said method compris the method as in claim 10 wherein the interconnect profil 42 and the complimentari interconnect profil compris a mate first dovetail configur 52 the method as in claim 10 or claim 11 further compris abut the root end 39 of the first base 32 against the chord-wis extend face of the align structur 38 the method as in ani of claim 10 to 12 further compris connect a plural of second base 34 to the first base 32 the method as in ani of claim 10 to 13 wherein the first base 32 and the plural of second base 34 are connect so as to align substanti parallel to a span-wis axi the method as in ani of claim 10 to 14 wherein the first base 32 and the plural of second base 34 are connect so as to maintain a chord-wis distanc from a trail edg of the rotor blade 22
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# a method 1000 for control a wind farm 300 400 the method compris the method 1000 of claim 1 wherein divid the wind farm compris at least one of the method 1000 of claim 1 or claim 2 wherein select the wind turbin 10 is perform in accord with a mainten state of the wind turbin 10 a load state of the wind turbin a wind condit of the wind turbin an error state of the wind turbin and or a curtail oper time of the wind turbin the method 1000 of ani preced claim wherein determin the actual power product of the first group of wind turbin compris at least one of the method 1000 of ani preced claim wherein estim the possibl maximum power product of the second group of wind turbin 10 compris at least one of the method 1000 of ani preced claim wherein estim the possibl maximum power output of the wind farm compris at least one of the method 1000 of ani preced claim wherein estim the power reserv compris at least one of the method 1000 of ani preced claim wherein determin the power setpoint compris at least one of a wind farm 300 400 compris
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# a method for control wind align correct of a wind turbin compris the method accord to claim 1 wherein the determin local maximum valu of the generat power valu extract for the respect wind speed section compris the method accord to claim 2 wherein the calcul the wind align correct deviat of the wind turbin base on the wind align angl measur valu extract for the respect wind speed section and correspond to the determin local maximum valu of the generat power valu compris the method accord to claim 3 wherein the correct the wind align angl measur valu to be acquir subsequ by use the wind align correct deviat compris the method accord to ani one of claim 1 to 4 further compris a devic for control wind align correct of a wind turbin compris the devic accord to claim 6 wherein the determin modul is configur to the devic accord to claim 7 wherein the calcul modul is configur to the devic accord to claim 8 wherein the correct modul is configur to the devic accord to ani one of claim 6 to 9 further compris a system for control wind align correct of wind turbin compris a cluster control and stand-alon control provid on the wind turbin wherein
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# an optic scan devic 11 compris an optic scan devic accord to claim 1 wherein an optic scan devic accord to claim 1 or 2 further compris a press member 23 capabl of chang a postur between a first postur in which the press member is mount at a predetermin posit of the hous and a second postur in which the press member is separ from the predetermin posit wherein an optic scan devic accord to claim 3 wherein an optic scan devic accord to claim 4 further compris an imag form apparatus compris
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail
# unavail

# %%
model.patent_list[1].patent_attributes
# Out:
# {'appln_id': 23867398,
#  'index_x': 12896,
#  'appln_id.1': 23867398.0,
#  'appln_auth': 'HR',
#  'appln_nr': 'P920702',
#  'appln_kind': 'A ',
#  'appln_filing_date': '1992-10-01',
#  'appln_filing_year': 1992,
#  'appln_nr_epodoc': 'HR1992P000702',
#  'appln_nr_original': '920702',
#  'ipr_type': 'PI',
#  'receiving_office': '  ',
#  'internat_appln_id': 0,
#  'int_phase': 'N',
#  'reg_phase': 'N',
#  'nat_phase': 'Y',
#  'earliest_filing_date': '1982-10-07',
#  'earliest_filing_year': 1982,
#  'earliest_filing_id': 54711657,
#  'earliest_publn_date': '1994-08-31',
#  'earliest_publn_year': 1994,
#  'earliest_pat_publn_id': 390763072,
#  'granted': 0,
#  'docdb_family_id': 26316819,
#  'inpadoc_family_id': 12366004,
#  'docdb_family_size': 1,
#  'nb_citing_docdb_fam': 0,
#  'nb_applicants': 1,
#  'nb_inventors': 1,
#  'appln_id.2': 23867398.0,
#  'appln_title_lg': 'en',
#  'appln_title': 'ROTARY WINDMILL WITH COLLAPSIBLE ARMS',
#  'appln_id.3': [],
#  'appln_abstract_lg': [],
#  'appln_abstract': [],
#  'appln_id.4': 23867398.0,
#  'ipc_class_symbol': 'F03D   3/06',
#  'ipc_class_level': 'A',
#  'ipc_version': '2006-01-01',
#  'ipc_value': 'I',
#  'ipc_position': ' ',
#  'ipc_gener_auth': 'EP',
#  'appln_id.5': 23867398.0,
#  'nace2_code': 28.1,
#  'weight': 1.0,
#  'pat_publn_id': 390763072,
#  'publn_auth': 'HR',
#  'publn_nr': 'P920702',
#  'publn_nr_original': [],
#  'publn_kind': 'A2',
#  'appln_id.6': 23867398,
#  'publn_date': '1994-08-31',
#  'publn_lg': '  ',
#  'publn_first_grant': 0,
#  'publn_claims': 0,
#  'nb_citing_docdb_fam_by_year': 0.0,
#  'index_y': 7483,
#  'docdb_family_id.1': [],
#  'cited_docdb_family_id': [],
#  'index': 12896,
#  'cpc_class_symbol': 'Y02E  10/74',
#  'cpc_scheme': 'CPC',
#  'cpc_version': '2013-01-01',
#  'cpc_value': 'I',
#  'cpc_position': 'F',
#  'cpc_gener_auth': '  ',
#  'person_id': [29366878.0, 29366877.0],
#  'applt_seq_nr': [0.0, 1.0],
#  'invt_seq_nr': [1.0, 0.0],
#  'person_id.1': [29366878.0, 29366877.0],
#  'person_name': ['MILJENKO, BARTULOVI}', 'BARTULOVI}, MILJENKO'],
#  'person_address': [],
#  'person_ctry_code': 'HR',
#  'doc_std_name_id': [11532335.0, 11532334.0],
#  'doc_std_name': ['MILJENKO BARTULOVI', 'BARTULOVI MILJENKO'],
#  'psn_id': [19257508.0, 1814790.0],
#  'psn_name': ['MILJENKO, BARTULOVI}', 'BARTULOVI}, MILJENKO'],
#  'psn_level': [0.0, 1.0],
#  'psn_sector': 'INDIVIDUAL',
#  'person_orig_id': [32298326.0, 32298325.0],
#  'person_id.2': [29366878.0, 29366877.0],
#  'source': 'DOCDB',
#  'source_version': [],
#  'name_freeform': ['MILJENKO, BARTULOVI}', 'BARTULOVI}, MILJENKO'],
#  'last_name': [],
#  'first_name': [],
#  'middle_name': [],
#  'address_freeform': [],
#  'address_1': [],
#  'address_2': [],
#  'address_3': [],
#  'address_4': [],
#  'address_5': [],
#  'street': [],
#  'city': [],
#  'zip_code': [],
#  'state': '  ',
#  'person_ctry_code.1': 'HR',
#  'residence_ctry_code': '  ',
#  'role': [],
#  'citing_docdb_families_ids': [],
#  'full_text': Empty DataFrame
#  Columns: [Unnamed: 0, publication_authority, publication_number, publication_kind, publication_date, language_text_component, text_type, text]
#  Index: [],
#  'full_text_claims': ['Unavailable'],
#  'stemmed text': 'unavail'}
